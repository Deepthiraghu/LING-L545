# %%
import numpy as np
import re
import math
import string
import random
from random import randrange
from pprint import pprint

# %%
n = [2,3,4]  # bigrams, trigrams and quadgrams
k = 40 # top 40 n-grams to calculate distance metric

# %%
def generate_n_grams(words, k, num_gram): # top k frequent n-grams
    ngrams = {}
    
    sentence = re.sub('['+string.punctuation+']', '', words)
    sentence = sentence.lower()
    sentence = re.sub('\s+', ' ', sentence).strip()
    sentence = sentence.replace(' ','_')

    for i in range(len(sentence) - num_gram):
        idx = sentence[i : i + num_gram]
        if idx in ngrams:
            ngrams[idx] += 1
        else:
            ngrams[idx] = 1
            
    total_freq = len(sentence) - num_gram + 1
    
    for key in ngrams.keys():
        reduction_factor = 1 
        if '_' in key: reduction_factor = 2
        ngrams[key] = round(math.log(ngrams[key] / (reduction_factor * total_freq)), 3)                             
        
    ngrams = sorted(ngrams.items(), key = lambda item : item[1], reverse = True) 

    final_ngrams = []
    log_probability = [] 
    
    for i in range(len(ngrams)):
        final_ngrams.append(ngrams[i][0])
        log_probability.append(ngrams[i][1])
        
    return final_ngrams, log_probability

# %%
bigrams = {}
trigrams = {}
quadgrams = {}

languages = ['assamese', 'odiya', 'punjabi', 'tamil']

for language in languages:
    with open ('input_' + language + '.txt', 'r') as filename:
        file = filename.read()
        bigrams[language] = generate_n_grams(file, k, n[0])
        trigrams[language] = generate_n_grams(file, k, n[1])
        quadgrams[language] = generate_n_grams(file, k, n[2])       
ngrams = {2 : bigrams, 3 : trigrams, 4 : quadgrams}

# %%
def calculate_distance(ngrams_test, ngrams_list, n):
    dist = {language: 0 for language in languages} 
    for ngram in ngrams_test[0]:
        for language in ngrams_list.keys():
            idx2 = ngrams_test[0].index(ngram)
            if ngram in ngrams[n][language][0] : 
                idx = ngrams[n][language][0].index(ngram)
                dist[language] += abs(ngrams[n][language][1][idx] - ngrams_test[1][idx2])
            else: 
                dist[language] += abs(ngrams_test[1][idx2])
    return dist

# %%
def identify_language(input_file, filetype):
    test_file = []  
    bigrams_test = []
    trigrams_test = []
    quadgrams_test = []
    total_distance = {}
    
    if filetype == 'file': 
        tempfile = input_file
        with open(tempfile, 'r', errors = 'ignore') as filename: 
            input_file = filename.read()

    bigrams_test = generate_n_grams(input_file, k, 2)
    trigrams_test = generate_n_grams(input_file, k, 3)
    quadgrams_test = generate_n_grams(input_file, k, 4)
    
    bigrams_distance = calculate_distance(bigrams_test, bigrams, 2) 
    trigrams_distance = calculate_distance(trigrams_test, trigrams, 3)
    quadgrams_distance = calculate_distance(quadgrams_test, quadgrams, 4) 

    for language in bigrams_distance.keys():
        total_distance[language] = bigrams_distance[language] + trigrams_distance[language] + quadgrams_distance[language]
    distance_sum = 0
    for distance in total_distance.values():
        distance_sum += distance
    for language in total_distance.keys():
        total_distance[language] /= distance_sum
    distance_list = sorted(total_distance.items(), key= lambda x:x[1])     

    print ('Predicted language :' + distance_list[0][0] + '\n')
    return distance_list[0][0]

# %%
inputfile = 'input_assamese.txt'
identify_language(inputfile, 'file')
# Out:
# Predicted language :assamese
# 'assamese'

# %%
inputfile = 'input_odiya.txt'
identify_language(inputfile, 'file')
# Out:
# Predicted language :odiya
# 'odiya'

# %%
inputfile = 'input_punjabi.txt'
identify_language(inputfile, 'file')
# Out:
# Predicted language :punjabi
# 'punjabi'

# %%
inputfile = 'input_tamil.txt'
identify_language(inputfile, 'file')
# Out:
# Predicted language :tamil
# 'tamil'

# %%
count = 0
accuracy = 0
misclassified = [] 

for i in range(1000):
    idx = randrange(0,4)
    language = languages[idx]
    file = "test_"+language+".txt"
    lines = random.choice(open(file, errors = "ignore").readlines())
    if len(lines) <= 20: 
        continue
    count += 1    
    print (lines)
    print ("Actual language : " + language )
    predicted = identify_language(lines, 'test_sentences')

    if (predicted == language): 
        accuracy += 1
    else:
        misclassified.append((lines, language, predicted))
# Out:
# here you all o of he a her n
#
# Actual language : tamil
# Predicted language :tamil
#
# a om who bar at an oit line oo
#
# Actual language : tamil
# Predicted language :punjabi
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# av moe to caofle  toval bush her ar ta hales ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# ge en her oo er o fir mos er monvers
#
# Actual language : assamese
# Predicted language :assamese
#
# boa of or her te shot evers e ton a
#
# Actual language : odiya
# Predicted language :punjabi
#
# hor rou or er bo for er orhor mo for hur whom o is i
#
# Actual language : assamese
# Predicted language :assamese
#
# wor ho morer lon preve raher
#
# Actual language : tamil
# Predicted language :assamese
#
# oa e sor o so wo mo ol or o wofor olon
#
# Actual language : assamese
# Predicted language :assamese
#
# i bote ash wot  ho tor caveawosh
#
# Actual language : odiya
# Predicted language :punjabi
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# womer her en tan ar a wo hed a a ver fanlees hel on has in
#
# Actual language : tamil
# Predicted language :tamil
#
# a wor wor e in hom on
#
# Actual language : assamese
# Predicted language :assamese
#
# wor as ac ca ra o too
#
# Actual language : tamil
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# pare youo over cane a you are oho o boroval er ar but antinho ish ercol a
#
# Actual language : odiya
# Predicted language :punjabi
#
# who re o te o o hos yo e
#
# Actual language : assamese
# Predicted language :assamese
#
# go po mor in o siler te over son ote feer who
#
# Actual language : assamese
# Predicted language :assamese
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# temar  canish ol yet hav e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# aah a ol crebl aateo el ra praen aal o
#
# Actual language : odiya
# Predicted language :punjabi
#
# o who wo did  sul boto heera tran e he trar  ar pass o no qi aper
#
# Actual language : odiya
# Predicted language :punjabi
#
# ihero a her her ow her eohor
#
# Actual language : tamil
# Predicted language :assamese
#
# wutene how an atol far ei i cas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# on who hor  me thon o o pobe
#
# Actual language : tamil
# Predicted language :assamese
#
# the nope har rop ru o wit per hapa howr
#
# Actual language : odiya
# Predicted language :punjabi
#
# wor as ac ca ra o too
#
# Actual language : tamil
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# the nol ar der have do at to e to all aa car
#
# Actual language : odiya
# Predicted language :punjabi
#
# yo an waol esis e har as e ho ner hofer her e ho
#
# Actual language : assamese
# Predicted language :punjabi
#
# ror an erb of rol an eamo lan or
#
# Actual language : tamil
# Predicted language :punjabi
#
# yo an waol esis e har as e ho ner hofer her e ho
#
# Actual language : assamese
# Predicted language :punjabi
#
# hhavor ol a ho drover on the
#
# Actual language : tamil
# Predicted language :assamese
#
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# hato hard lo over ar gern a a os but her e er  cot toe era to o
#
# Actual language : odiya
# Predicted language :odiya
#
# how wo i s besh mish  i pan har
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goom al ole on orofer e horm
#
# Actual language : assamese
# Predicted language :assamese
#
# temar  canish ol yet hav e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o fowol aar te a to a ar ton tatibo e troa ca
#
# Actual language : odiya
# Predicted language :punjabi
#
# eer lar man o yeur or i
#
# Actual language : tamil
# Predicted language :assamese
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ah andwee rop yr a for lottle on  herm of tro
#
# Actual language : punjabi
# Predicted language :assamese
#
# o gar ta her tash are e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ah boosh so la a ant o  o eve tad yo et  a yoare
#
# Actual language : odiya
# Predicted language :punjabi
#
# bol il bole  ado gor aar or trac to rol  er l a your aer or
#
# Actual language : odiya
# Predicted language :odiya
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a o i poher han had tol eo s ta
#
# Actual language : odiya
# Predicted language :punjabi
#
# her on er wol movig had a er a no e
#
# Actual language : tamil
# Predicted language :tamil
#
#  pe o maser e ofol te
#
# Actual language : tamil
# Predicted language :punjabi
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# er ave e in el er hes aner in he en aneahe an has that ma
#
# Actual language : tamil
# Predicted language :punjabi
#
# o all no you yor o or
#
# Actual language : tamil
# Predicted language :assamese
#
# the gral wel oo ora o movn
#
# Actual language : tamil
# Predicted language :assamese
#
# oho mo ies o horan ho ero in wo
#
# Actual language : assamese
# Predicted language :assamese
#
# got can ar e more e cara o bo to ave i porola ers far bote a
#
# Actual language : odiya
# Predicted language :odiya
#
# wer roomer il for rover to woer te lom es atiser o
#
# Actual language : assamese
# Predicted language :assamese
#
# omo more oro is n i hom to wo te wor mo tho moso  her ho
#
# Actual language : assamese
# Predicted language :assamese
#
# i wol are pi tol hol  to at er on atter the at bicto the hold ho er
#
# Actual language : odiya
# Predicted language :punjabi
#
# a warer ors ter an hof won et
#
# Actual language : tamil
# Predicted language :punjabi
#
# o on fomo a  haro her
#
# Actual language : tamil
# Predicted language :punjabi
#
# momer haero mor chilerol in
#
# Actual language : tamil
# Predicted language :assamese
#
# buti how for go par at o le i a al ete to are
#
# Actual language : odiya
# Predicted language :punjabi
#
# ala a ltl e ar atat bo wo ar trar yo ber ar cacter oro dele shata i a ar a
#
# Actual language : odiya
# Predicted language :odiya
#
# mo ol he e ol pes ad ser sho setat
#
# Actual language : punjabi
# Predicted language :punjabi
#
# got can ar e more e cara o bo to ave i porola ers far bote a
#
# Actual language : odiya
# Predicted language :odiya
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# how ver e oo a hor wo bo to fo a od cosho s te a wova a shartol tan fro to o tla a
#
# Actual language : odiya
# Predicted language :odiya
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a po al oh who ho bas a so obl o o o so oner e l at lo aer
#
# Actual language : odiya
# Predicted language :odiya
#
# how wo i s besh mish  i pan har
#
# Actual language : punjabi
# Predicted language :punjabi
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wutene how an atol far ei i cas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# go po mor in o siler te over son ote feer who
#
# Actual language : assamese
# Predicted language :assamese
#
# mo moo herm the wor lon relo la ar o eere ol ol fool ros fon
#
# Actual language : tamil
# Predicted language :assamese
#
# oa ran o on o to ong  lo can yote her tan er the wor
#
# Actual language : tamil
# Predicted language :tamil
#
# i aall moru bat gorhola o ato a  soshe hor la o
#
# Actual language : odiya
# Predicted language :punjabi
#
# wo eo atero en o tooer tee ho or fer forter te
#
# Actual language : assamese
# Predicted language :assamese
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# atol tru wor a oho na a o e bo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# hah o lottebo wol e ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# coma o apo e me pa too a  torher toar ose
#
# Actual language : odiya
# Predicted language :punjabi
#
# or wot for boto wo es fel ol tol om
#
# Actual language : assamese
# Predicted language :assamese
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ru wor er zo sorin mo her her o he her her mor yoer her her who
#
# Actual language : assamese
# Predicted language :assamese
#
# hah o lottebo wol e ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# omo more oro is n i hom to wo te wor mo tho moso  her ho
#
# Actual language : assamese
# Predicted language :assamese
#
# sha ave toable gro o e to e apa
#
# Actual language : odiya
# Predicted language :punjabi
#
# bo won wo onol or her troot oso   oo o or
#
# Actual language : assamese
# Predicted language :assamese
#
# a wor wor e in hom on
#
# Actual language : assamese
# Predicted language :assamese
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# temar  canish ol yet hav e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ther her msasse has reso
#
# Actual language : assamese
# Predicted language :punjabi
#
# eomo and o or to her
#
# Actual language : assamese
# Predicted language :assamese
#
# blu ate slaro wo pa cravel shel a herwo ater a aten a
#
# Actual language : odiya
# Predicted language :punjabi
#
# ge en her oo er o fir mos er monvers
#
# Actual language : assamese
# Predicted language :assamese
#
# oh who ro ahe i iver ata a
#
# Actual language : tamil
# Predicted language :punjabi
#
# ho glar i o clas o to in ye ar tat e tle or
#
# Actual language : odiya
# Predicted language :punjabi
#
# opar rove l heer te  tear aa terpefoco e ler or
#
# Actual language : odiya
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# rer consiner i eres ane i nin met
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o wo o o  fol avr aer
#
# Actual language : tamil
# Predicted language :assamese
#
# or wot for boto wo es fel ol tol om
#
# Actual language : assamese
# Predicted language :assamese
#
# ah o who on o ro hom
#
# Actual language : tamil
# Predicted language :assamese
#
# wor a aro han on ha fel
#
# Actual language : tamil
# Predicted language :tamil
#
# a cal blo cup o pato a to eat blo ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wer roomer il for rover to woer te lom es atiser o
#
# Actual language : assamese
# Predicted language :assamese
#
# a cala lou a o ho ol eri
#
# Actual language : tamil
# Predicted language :assamese
#
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# rom  who ao wo  wo more o worble o who ano o
#
# Actual language : tamil
# Predicted language :assamese
#
# ah o e pool a to or tat to or
#
# Actual language : odiya
# Predicted language :odiya
#
# to wom ooeras ril er wo ofo fhoh
#
# Actual language : assamese
# Predicted language :assamese
#
# wor ho morer lon preve raher
#
# Actual language : tamil
# Predicted language :assamese
#
# not co betoa ta aol ra bo yo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# o furn no erver cam o ar
#
# Actual language : tamil
# Predicted language :punjabi
#
# oome or er asterte co er ser
#
# Actual language : assamese
# Predicted language :punjabi
#
# a mirl hon worve mo wor ol ol o han a all
#
# Actual language : tamil
# Predicted language :assamese
#
# her verther e peraby drew at
#
# Actual language : tamil
# Predicted language :punjabi
#
# blo wol torar a ar ar over oo a cof tom the ho her moshol
#
# Actual language : odiya
# Predicted language :odiya
#
# wo ite sero son to o
#
# Actual language : assamese
# Predicted language :punjabi
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ersesin ter for wo moto tom o
#
# Actual language : assamese
# Predicted language :assamese
#
# bar ho copraa o purver i ter par e feto er to rol or
#
# Actual language : odiya
# Predicted language :punjabi
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ooo en so eoe o wron
#
# Actual language : tamil
# Predicted language :assamese
#
# ro more or es sil first ton o
#
# Actual language : assamese
# Predicted language :punjabi
#
# wo omer infaconye to to
#
# Actual language : assamese
# Predicted language :punjabi
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# oho fa o i fi oh too  hor o on fol
#
# Actual language : tamil
# Predicted language :assamese
#
# wo pesul who fin oosin thevos te
#
# Actual language : assamese
# Predicted language :punjabi
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# moer oher r moah av er
#
# Actual language : tamil
# Predicted language :punjabi
#
# ma e ser ans ana but
#
# Actual language : punjabi
# Predicted language :punjabi
#
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a glota a ad cate toble goher a
#
# Actual language : odiya
# Predicted language :punjabi
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ol wo trew ua ter of a ro ba t who ye
#
# Actual language : tamil
# Predicted language :punjabi
#
# par not you iterl ol
#
# Actual language : odiya
# Predicted language :punjabi
#
# bok cavl ac al  ol to co col toco taa
#
# Actual language : odiya
# Predicted language :punjabi
#
# hower o erot ta rerter
#
# Actual language : odiya
# Predicted language :punjabi
#
# moel o e  a a e e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
#   e to cel he e wosh you
#
# Actual language : tamil
# Predicted language :punjabi
#
# owe her so wi the lo
#
# Actual language : tamil
# Predicted language :punjabi
#
# run at er lo or a lote hane ad mu sutli ah
#
# Actual language : tamil
# Predicted language :punjabi
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ihero a her her ow her eohor
#
# Actual language : tamil
# Predicted language :assamese
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# or wot for boto wo es fel ol tol om
#
# Actual language : assamese
# Predicted language :assamese
#
# sha ave toable gro o e to e apa
#
# Actual language : odiya
# Predicted language :punjabi
#
# moel o e  a a e e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ma her ro as an of er eil a
#
# Actual language : tamil
# Predicted language :punjabi
#
# the par i o bor on eo o i e wal  a a
#
# Actual language : odiya
# Predicted language :tamil
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ah o who on o ro hom
#
# Actual language : tamil
# Predicted language :assamese
#
# ro more or es sil first ton o
#
# Actual language : assamese
# Predicted language :punjabi
#
# ah o e pool a to or tat to or
#
# Actual language : odiya
# Predicted language :odiya
#
# sha ave toable gro o e to e apa
#
# Actual language : odiya
# Predicted language :punjabi
#
# ash a ben tec to to ash no ol  se
#
# Actual language : punjabi
# Predicted language :punjabi
#
# yer e her tol the rar ol oer herm thel ar ha om sha of e ere
#
# Actual language : tamil
# Predicted language :punjabi
#
# othe er or the woon ater hoso her e er ter her mot o a moe
#
# Actual language : assamese
# Predicted language :punjabi
#
# a cal blo cup o pato a to eat blo ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# at oh te can co al toom at the to had do tho ta bat he  cowera
#
# Actual language : odiya
# Predicted language :punjabi
#
# glu ta to ho lo ar car that te e tu to
#
# Actual language : odiya
# Predicted language :odiya
#
# oho mo ies o horan ho ero in wo
#
# Actual language : assamese
# Predicted language :assamese
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# her the pass a word o me a te er are
#
# Actual language : tamil
# Predicted language :punjabi
#
# or i wonl ever o fer yer a
#
# Actual language : tamil
# Predicted language :assamese
#
# oper wo wor en ho ol e fol
#
# Actual language : assamese
# Predicted language :assamese
#
# mo ol he e ol pes ad ser sho setat
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# rom topel ago cabor war tot a a ar e ol toble bol hara
#
# Actual language : odiya
# Predicted language :odiya
#
# wo o for fono  asol hes
#
# Actual language : tamil
# Predicted language :assamese
#
# wo o for fono  asol hes
#
# Actual language : tamil
# Predicted language :assamese
#
# oome or er asterte co er ser
#
# Actual language : assamese
# Predicted language :punjabi
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# awork wo o prorol o o
#
# Actual language : assamese
# Predicted language :assamese
#
# bon la re sho s ru  no
#
# Actual language : tamil
# Predicted language :punjabi
#
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a man tatco tarte as posh ea me
#
# Actual language : odiya
# Predicted language :punjabi
#
# wo wo wo om o more an
#
# Actual language : assamese
# Predicted language :assamese
#
# her terer good her hor won in e om oon coe rus oroer
#
# Actual language : assamese
# Predicted language :assamese
#
# rutel aw  e e ol on e ha an an
#
# Actual language : tamil
# Predicted language :punjabi
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ge en her oo er o fir mos er monvers
#
# Actual language : assamese
# Predicted language :assamese
#
# wole a plocpa co cower coa ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# wo re oh ooh wo a alo lin ara
#
# Actual language : tamil
# Predicted language :punjabi
#
# wo omer infaconye to to
#
# Actual language : assamese
# Predicted language :punjabi
#
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# you or on true o ere
#
# Actual language : tamil
# Predicted language :assamese
#
# mo ol he e ol pes ad ser sho setat
#
# Actual language : punjabi
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# rom  who ao wo  wo more o worble o who ano o
#
# Actual language : tamil
# Predicted language :assamese
#
# wole a plocpa co cower coa ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# wutene how an atol far ei i cas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# tho la car leha the ol  sho blo ar cover lo bor a sthe oop a to a por
#
# Actual language : odiya
# Predicted language :odiya
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o wor mordern for is on wo for weor wo abben a hes he sor
#
# Actual language : assamese
# Predicted language :assamese
#
# a ah ol ot have long
#
# Actual language : tamil
# Predicted language :odiya
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi
#
# maol wa or awa ha so pas ol or
#
# Actual language : tamil
# Predicted language :punjabi
#
# emoo who forho we or ser ofnfir eher e a her e wos or
#
# Actual language : assamese
# Predicted language :assamese
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# emoo who forho we or ser ofnfir eher e a her e wos or
#
# Actual language : assamese
# Predicted language :assamese
#
# e mo bron artar to wer of sot tave palo boer to aa
#
# Actual language : odiya
# Predicted language :punjabi
#
# o o e a as o ho fo hor e ol o ans eer
#
# Actual language : assamese
# Predicted language :assamese
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a gol  had wo a hasho a tut ol ar to we a tu ro por caa anor a e a ar
#
# Actual language : odiya
# Predicted language :odiya
#
# ah andwee rop yr a for lottle on  herm of tro
#
# Actual language : punjabi
# Predicted language :assamese
#
# oh who ro ahe i iver ata a
#
# Actual language : tamil
# Predicted language :punjabi
#
# mo moo herm the wor lon relo la ar o eere ol ol fool ros fon
#
# Actual language : tamil
# Predicted language :assamese
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a glota a ad cate toble goher a
#
# Actual language : odiya
# Predicted language :punjabi
#
# the nope har rop ru o wit per hapa howr
#
# Actual language : odiya
# Predicted language :punjabi
#
# glu ta to ho lo ar car that te e tu to
#
# Actual language : odiya
# Predicted language :odiya
#
# a mora ate a cau de li goere ta aro
#
# Actual language : odiya
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# h e yeah ho his go ter a her did your a arter
#
# Actual language : tamil
# Predicted language :punjabi
#
# moror wor wor hom  her her om eon pro horro
#
# Actual language : assamese
# Predicted language :assamese
#
# o mo no wo o mo o hor o
#
# Actual language : assamese
# Predicted language :assamese
#
# ma her ro as an of er eil a
#
# Actual language : tamil
# Predicted language :punjabi
#
# areod oe mo boof o or rola aoo om trog to
#
# Actual language : tamil
# Predicted language :assamese
#
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# aah a ol crebl aateo el ra praen aal o
#
# Actual language : odiya
# Predicted language :punjabi
#
# te ac fanl ar a a fronan who ha  trol or fo a ah te te er to ater ar
#
# Actual language : odiya
# Predicted language :odiya
#
# arer o o wol af a ihar ho
#
# Actual language : tamil
# Predicted language :punjabi
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# rer consiner i eres ane i nin met
#
# Actual language : punjabi
# Predicted language :punjabi
#
# who i te a sufer pe to merper who e
#
# Actual language : assamese
# Predicted language :punjabi
#
# atol tru wor a oho na a o e bo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# bon la re sho s ru  no
#
# Actual language : tamil
# Predicted language :punjabi
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# ho glar i o clas o to in ye ar tat e tle or
#
# Actual language : odiya
# Predicted language :punjabi
#
# eomo and o or to her
#
# Actual language : assamese
# Predicted language :assamese
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o gar ta her tash are e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ewa ar coble trua tet part o birls
#
# Actual language : odiya
# Predicted language :punjabi
#
# moo o o o to e wo otu te has yo er
#
# Actual language : assamese
# Predicted language :assamese
#
# her terer good her hor won in e om oon coe rus oroer
#
# Actual language : assamese
# Predicted language :assamese
#
# as a dron rep ten wol ho of a
#
# Actual language : punjabi
# Predicted language :assamese
#
# ale wo i aoe at a atot co you o e lat
#
# Actual language : odiya
# Predicted language :punjabi
#
# wowho her ar fo he ho ro m her
#
# Actual language : assamese
# Predicted language :assamese
#
# ash a ben tec to to ash no ol  se
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o wor mordern for is on wo for weor wo abben a hes he sor
#
# Actual language : assamese
# Predicted language :assamese
#
# atol tru wor a oho na a o e bo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# er won ho on o e thel wer  po the fil or her o the paseo or hoo
#
# Actual language : assamese
# Predicted language :assamese
#
# por momon tral bir power gol a teer e e toote pare her
# Actual language : odiya
# Predicted language :punjabi
#
# awho yo o gre o te o tan to er
#
# Actual language : assamese
# Predicted language :punjabi
#
# who re o te o o hos yo e
#
# Actual language : assamese
# Predicted language :assamese
#
# mo son ron to in o o
#
# Actual language : tamil
# Predicted language :punjabi
#
# a women non e bor ter on  terter
#
# Actual language : tamil
# Predicted language :punjabi
#
# mo ol he e ol pes ad ser sho setat
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ther her msasse has reso
#
# Actual language : assamese
# Predicted language :punjabi
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# yer e her tol the rar ol oer herm thel ar ha om sha of e ere
#
# Actual language : tamil
# Predicted language :punjabi
#
# ersesin ter for wo moto tom o
#
# Actual language : assamese
# Predicted language :assamese
#
# rer consiner i eres ane i nin met
#
# Actual language : punjabi
# Predicted language :punjabi
#
# e ar o o a o and te hav a
#
# Actual language : tamil
# Predicted language :punjabi
#
# got can ar e more e cara o bo to ave i porola ers far bote a
#
# Actual language : odiya
# Predicted language :odiya
#
# mor wor an o on so mos sis ten ho herall pos fim wo
#
# Actual language : assamese
# Predicted language :assamese
#
# o mo no wo o mo o hor o
#
# Actual language : assamese
# Predicted language :assamese
#
# oa e sor o so wo mo ol or o wofor olon
#
# Actual language : assamese
# Predicted language :assamese
#
# av moe to caofle  toval bush her ar ta hales ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# a gol  had wo a hasho a tut ol ar to we a tu ro por caa anor a e a ar
#
# Actual language : odiya
# Predicted language :odiya
#
# mo woo ors mo as he o ser gro
#
# Actual language : assamese
# Predicted language :assamese
#
# o gar ta her tash are e
#
# Actual language : punjabi
# Predicted language :punjabi
#
#  hor wer on not non hoor an more terepor it
#
# Actual language : tamil
# Predicted language :assamese
#
# ah o who on o ro hom
#
# Actual language : tamil
# Predicted language :assamese
#
# a mora ate a cau de li goere ta aro
#
# Actual language : odiya
# Predicted language :punjabi
#
# hah o lottebo wol e ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# o gar ta her tash are e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# boa of or her te shot evers e ton a
#
# Actual language : odiya
# Predicted language :punjabi
#
# man at fot te wod toca dear cral o
#
# Actual language : odiya
# Predicted language :punjabi
#
# ash a ben tec to to ash no ol  se
#
# Actual language : punjabi
# Predicted language :punjabi
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# the wo wer ar oe  ol er on all e
#
# Actual language : tamil
# Predicted language :tamil
#
# oho mo ies o horan ho ero in wo
#
# Actual language : assamese
# Predicted language :assamese
#
# a women non e bor ter on  terter
#
# Actual language : tamil
# Predicted language :punjabi
#
# ha par ho go at a pa ca foe  pa  bluo ol a a
#
# Actual language : odiya
# Predicted language :punjabi
#
# o erbl u are han aongo ith e  none eron
#
# Actual language : tamil
# Predicted language :punjabi
#
# got can ar e more e cara o bo to ave i porola ers far bote a
#
# Actual language : odiya
# Predicted language :odiya
#
# worer has a no all her ee
#
# Actual language : tamil
# Predicted language :tamil
#
# i aall moru bat gorhola o ato a  soshe hor la o
#
# Actual language : odiya
# Predicted language :punjabi
#
# mohare wittle go hor er
#
# Actual language : tamil
# Predicted language :assamese
#
# emoo who forho we or ser ofnfir eher e a her e wos or
#
# Actual language : assamese
# Predicted language :assamese
#
# boa of or her te shot evers e ton a
#
# Actual language : odiya
# Predicted language :punjabi
#
# o gar ta her tash are e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a rol mor i hel her on the hon  ha paat han her
#
# Actual language : tamil
# Predicted language :tamil
#
# ho l mun o durn yera os o a
#
# Actual language : tamil
# Predicted language :assamese
#
# ala a ltl e ar atat bo wo ar trar yo ber ar cacter oro dele shata i a ar a
#
# Actual language : odiya
# Predicted language :odiya
#
# ma e ser ans ana but
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# her gil ar a o wa wor
#
# Actual language : tamil
# Predicted language :punjabi
#
# o fowol aar te a to a ar ton tatibo e troa ca
#
# Actual language : odiya
# Predicted language :punjabi
#
# oome or er asterte co er ser
#
# Actual language : assamese
# Predicted language :punjabi
#
# a glota a ad cate toble goher a
#
# Actual language : odiya
# Predicted language :punjabi
#
# h e yeah ho his go ter a her did your a arter
#
# Actual language : tamil
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# a bol e go tar o po taol a tata troo be kan opa ha sush lom o
#
# Actual language : odiya
# Predicted language :odiya
#
# roo we il foe a om who
#
# Actual language : assamese
# Predicted language :assamese
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# on who hor  me thon o o pobe
#
# Actual language : tamil
# Predicted language :assamese
#
# hato hard lo over ar gern a a os but her e er  cot toe era to o
#
# Actual language : odiya
# Predicted language :odiya
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a women non e bor ter on  terter
#
# Actual language : tamil
# Predicted language :punjabi
#
# ah o e pool a to or tat to or
#
# Actual language : odiya
# Predicted language :odiya
#
# i you on a tho o on a
#
# Actual language : tamil
# Predicted language :tamil
#
# lo o e om a patola o ean ro e ah out
#
# Actual language : odiya
# Predicted language :punjabi
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# bok cavl ac al  ol to co col toco taa
#
# Actual language : odiya
# Predicted language :punjabi
#
# go o cole lo a ca alee bro be ar a a
#
# Actual language : odiya
# Predicted language :odiya
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# go po mor in o siler te over son ote feer who
#
# Actual language : assamese
# Predicted language :assamese
#
# oho mo ies o horan ho ero in wo
#
# Actual language : assamese
# Predicted language :assamese
#
# a glota a ad cate toble goher a
#
# Actual language : odiya
# Predicted language :punjabi
#
# moel o e  a a e e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# blue borbl had her a pa te hava wit tethe ta acatl powol a terar
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah a gor eten to a so soma e hol rul har yo sho bom o
#
# Actual language : odiya
# Predicted language :punjabi
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# her  who o wo how ham ao har food
#
# Actual language : tamil
# Predicted language :assamese
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# awork wo o prorol o o
#
# Actual language : assamese
# Predicted language :assamese
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wo eo atero en o tooer tee ho or fer forter te
#
# Actual language : assamese
# Predicted language :assamese
#
# ah con or te a ler broa to pa o asen o heal car
#
# Actual language : odiya
# Predicted language :odiya
#
# al ger o o er a shoe er to her on
#
# Actual language : tamil
# Predicted language :assamese
#
# rewl pa ha e a or an si feral fa ee
#
# Actual language : tamil
# Predicted language :punjabi
#
# oar wan ale ho wer o in herlon her
#
# Actual language : tamil
# Predicted language :punjabi
#
# her bo wor her who o wo
#
# Actual language : assamese
# Predicted language :assamese
#
# moror wor wor hom  her her om eon pro horro
#
# Actual language : assamese
# Predicted language :assamese
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# i wol are pi tol hol  to at er on atter the at bicto the hold ho er
#
# Actual language : odiya
# Predicted language :punjabi
#
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# frome e a te o to ar paa hat  over fur otos o te do oshul bo or
#
# Actual language : odiya
# Predicted language :odiya
#
# o fowol aar te a to a ar ton tatibo e troa ca
#
# Actual language : odiya
# Predicted language :punjabi
#
# as a dron rep ten wol ho of a
#
# Actual language : punjabi
# Predicted language :assamese
#
# temar  canish ol yet hav e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# or er oo for as is in e fo
#
# Actual language : assamese
# Predicted language :punjabi
#
# yo an waol esis e har as e ho ner hofer her e ho
#
# Actual language : assamese
# Predicted language :punjabi
#
# hah o lottebo wol e ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# a o er an has long a ot ho aton
#
# Actual language : tamil
# Predicted language :punjabi
#
# pare youo over cane a you are oho o boroval er ar but antinho ish ercol a
#
# Actual language : odiya
# Predicted language :punjabi
#
# rom topel ago cabor war tot a a ar e ol toble bol hara
#
# Actual language : odiya
# Predicted language :odiya
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# haner wol revero o ow aner ol  an
#
# Actual language : tamil
# Predicted language :assamese
#
# frome e a te o to ar paa hat  over fur otos o te do oshul bo or
#
# Actual language : odiya
# Predicted language :odiya
#
# afte an pos scru wal hal go ahop ape od roe sar
#
# Actual language : odiya
# Predicted language :punjabi
#
# o wo o o  fol avr aer
#
# Actual language : tamil
# Predicted language :assamese
#
# bar ho copraa o purver i ter par e feto er to rol or
#
# Actual language : odiya
# Predicted language :punjabi
#
# oois o who herfor ho wor on motel for mon
#
# Actual language : assamese
# Predicted language :assamese
#
# you or on true o ere
#
# Actual language : tamil
# Predicted language :assamese
#
# ahe yer e year is e as
#
# Actual language : tamil
# Predicted language :punjabi
#
# o e ans s eviden ite ro a d he  ba edes tip wis ri  e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o gar ta her tash are e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# wowho her ar fo he ho ro m her
#
# Actual language : assamese
# Predicted language :assamese
#
# or love te eatom thera
#
# Actual language : odiya
# Predicted language :punjabi
#
# gro wor or at proper at wee a wor ru bo
#
# Actual language : tamil
# Predicted language :assamese
#
# gro and group en mom te  fer vo you hon over bo
#
# Actual language : assamese
# Predicted language :assamese
#
# hah o lottebo wol e ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# or wot for boto wo es fel ol tol om
#
# Actual language : assamese
# Predicted language :assamese
#
# abat caprad eor craps foh rul bos ot te a oer a ca to
#
# Actual language : odiya
# Predicted language :punjabi
# o who wo did  sul boto heera tran e he trar  ar pass o no qi aper
#
# Actual language : odiya
# Predicted language :punjabi
#
# a mon or a wol wel if your ae
#
# Actual language : tamil
# Predicted language :assamese
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# tat hor book a gru pepoprable er
#
# Actual language : odiya
# Predicted language :assamese
#
# om d mein a cal ha tas ha oi at roa at o ta lush
#
# Actual language : odiya
# Predicted language :punjabi
#
# wo omo mofol  o on who
#
# Actual language : assamese
# Predicted language :assamese
#
# l are that trouble boles si a ol to for the the te blo o ar go  a
#
# Actual language : odiya
# Predicted language :odiya
#
# ou  mo her mir o your
#
# Actual language : assamese
# Predicted language :assamese
#
# or herer as the hom i o
#
# Actual language : assamese
# Predicted language :punjabi
#
# goger who ro lot moover fermn earl o
#
# Actual language : tamil
# Predicted language :assamese
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# a rol mor i hel her on the hon  ha paat han her
#
# Actual language : tamil
# Predicted language :tamil
#
# to wom ooeras ril er wo ofo fhoh
#
# Actual language : assamese
# Predicted language :assamese
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# par not you iterl ol
#
# Actual language : odiya
# Predicted language :punjabi
#
# wo eo atero en o tooer tee ho or fer forter te
#
# Actual language : assamese
# Predicted language :assamese
#
# or er oo for as is in e fo
#
# Actual language : assamese
# Predicted language :punjabi
#
# awho yo o gre o te o tan to er
#
# Actual language : assamese
# Predicted language :punjabi
#
# o wor mordern for is on wo for weor wo abben a hes he sor
#
# Actual language : assamese
# Predicted language :assamese
#
# owe her so wi the lo
#
# Actual language : tamil
# Predicted language :punjabi
#
# oom hon er a or wo who l and er
#
# Actual language : tamil
# Predicted language :assamese
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a gol  had wo a hasho a tut ol ar to we a tu ro por caa anor a e a ar
#
# Actual language : odiya
# Predicted language :odiya
#
#  a ov hol er ivl totes shop o  ho e he the a tavel a or year o sho how
#
# Actual language : odiya
# Predicted language :punjabi
#
# por momon tral bir power gol a teer e e toote pare her
# Actual language : odiya
# Predicted language :punjabi
#
# ge en her oo er o fir mos er monvers
#
# Actual language : assamese
# Predicted language :assamese
#
# i aall moru bat gorhola o ato a  soshe hor la o
#
# Actual language : odiya
# Predicted language :punjabi
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ooo o o ofor tomer vordof mo povers e afom teon cns e
#
# Actual language : assamese
# Predicted language :assamese
#
# ho l mun o durn yera os o a
#
# Actual language : tamil
# Predicted language :assamese
#
# rofer hom mor fo or oore mor ars e har emoer mor
#
# Actual language : assamese
# Predicted language :assamese
#
# wo eo atero en o tooer tee ho or fer forter te
#
# Actual language : assamese
# Predicted language :assamese
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# who i te a sufer pe to merper who e
#
# Actual language : assamese
# Predicted language :punjabi
#
# who ho la ol eyar oro
#
# Actual language : tamil
# Predicted language :assamese
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ao how ha a on hoye who o ier ate
#
# Actual language : tamil
# Predicted language :punjabi
#
# hower ol an on a ture bre su
#
# Actual language : tamil
# Predicted language :punjabi
#
# hew ver truner ar o o ar a caraitriher ol her wo ato ar a an co sho the e or
#
# Actual language : odiya
# Predicted language :odiya
#
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# grooto to er  for who ase tho ter mos tor oe
#
# Actual language : assamese
# Predicted language :assamese
#
# oome or er asterte co er ser
#
# Actual language : assamese
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# her verther e peraby drew at
#
# Actual language : tamil
# Predicted language :punjabi
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ana man a rad oable eh co s asho a o a ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# or i wonl ever o fer yer a
#
# Actual language : tamil
# Predicted language :assamese
#
# a her ho heever hor be a o ov a bon an an en an
#
# Actual language : tamil
# Predicted language :tamil
#
# sha ave toable gro o e to e apa
#
# Actual language : odiya
# Predicted language :punjabi
#
# ash a ben tec to to ash no ol  se
#
# Actual language : punjabi
# Predicted language :punjabi
#
# av moe to caofle  toval bush her ar ta hales ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# har women or mo wer sa o wo we m o
#
# Actual language : tamil
# Predicted language :assamese
#
# or wot for boto wo es fel ol tol om
#
# Actual language : assamese
# Predicted language :assamese
#
# ru wor er zo sorin mo her her o he her her mor yoer her her who
#
# Actual language : assamese
# Predicted language :assamese
#
# hhavor ol a ho drover on the
#
# Actual language : tamil
# Predicted language :assamese
#
# wo ite sero son to o
#
# Actual language : assamese
# Predicted language :punjabi
#
# oho fa o i fi oh too  hor o on fol
#
# Actual language : tamil
# Predicted language :assamese
#
# opar rove l heer te  tear aa terpefoco e ler or
#
# Actual language : odiya
# Predicted language :punjabi
#
# uaia her a had i will  mae
#
# Actual language : tamil
# Predicted language :punjabi
#
# mo o o wo war n o for
#
# Actual language : tamil
# Predicted language :assamese
#
# rorl o o ol pole le eea
#
# Actual language : tamil
# Predicted language :assamese
#
# oo wom mov hom an o prefoeres eoser as eoer
#
# Actual language : assamese
# Predicted language :assamese
#
# oa e sor o so wo mo ol or o wofor olon
#
# Actual language : assamese
# Predicted language :assamese
#
# buti how for go par at o le i a al ete to are
#
# Actual language : odiya
# Predicted language :punjabi
#
# ruba wil wol a a  a lo ho e
#
# Actual language : tamil
# Predicted language :punjabi
#
# om d mein a cal ha tas ha oi at roa at o ta lush
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wo who for nor mor wo e here o enfor ma yen
#
# Actual language : assamese
# Predicted language :assamese
#
# al ron oper eor rel throg te or
#
# Actual language : tamil
# Predicted language :assamese
#
# got can ar e more e cara o bo to ave i porola ers far bote a
#
# Actual language : odiya
# Predicted language :odiya
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ewa ar coble trua tet part o birls
#
# Actual language : odiya
# Predicted language :punjabi
#
# haner wol revero o ow aner ol  an
#
# Actual language : tamil
# Predicted language :assamese
#
# or i wonl ever o fer yer a
#
# Actual language : tamil
# Predicted language :assamese
#
# i you on a tho o on a
#
# Actual language : tamil
# Predicted language :tamil
#
# bo won wo onol or her troot oso   oo o or
#
# Actual language : assamese
# Predicted language :assamese
#
# wo hatha coa o oer o erer
#
# Actual language : odiya
# Predicted language :assamese
#
# comelohas wole trome  tra to sho to ho o ar par perver troo
#
# Actual language : odiya
# Predicted language :odiya
#
# ah andwee rop yr a for lottle on  herm of tro
#
# Actual language : punjabi
# Predicted language :assamese
#
# how ver e oo a hor wo bo to fo a od cosho s te a wova a shartol tan fro to o tla a
#
# Actual language : odiya
# Predicted language :odiya
#
# goger who ro lot moover fermn earl o
#
# Actual language : tamil
# Predicted language :assamese
#
# comelohas wole trome  tra to sho to ho o ar par perver troo
#
# Actual language : odiya
# Predicted language :odiya
#
# ha par ho go at a pa ca foe  pa  bluo ol a a
#
# Actual language : odiya
# Predicted language :punjabi
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# tat hor book a gru pepoprable er
#
# Actual language : odiya
# Predicted language :assamese
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# not co betoa ta aol ra bo yo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# lac as hope i go a ton
#
# Actual language : odiya
# Predicted language :punjabi
#
# oo gro or wot fo te es er her hor e
#
# Actual language : assamese
# Predicted language :assamese
#
# wo wo wo om o more an
#
# Actual language : assamese
# Predicted language :assamese
#
# bok cavl ac al  ol to co col toco taa
#
# Actual language : odiya
# Predicted language :punjabi
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wowho her ar fo he ho ro m her
#
# Actual language : assamese
# Predicted language :assamese
#
#  a ov hol er ivl totes shop o  ho e he the a tavel a or year o sho how
#
# Actual language : odiya
# Predicted language :punjabi
#
# he low car e oborm over  be ah wo a o o ooper toe ol
#
# Actual language : odiya
# Predicted language :odiya
#
# col co n ar ar home ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# maol wa or awa ha so pas ol or
#
# Actual language : tamil
# Predicted language :punjabi
#
# buro owo o  wo where a more me o hor od
#
# Actual language : tamil
# Predicted language :assamese
#
# abat caprad eor craps foh rul bos ot te a oer a ca to
#
# Actual language : odiya
# Predicted language :punjabi
#
# grooto to er  for who ase tho ter mos tor oe
#
# Actual language : assamese
# Predicted language :assamese
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# te ac fanl ar a a fronan who ha  trol or fo a ah te te er to ater ar
#
# Actual language : odiya
# Predicted language :odiya
#
# mo wol mo ror as over en worl fo
#
# Actual language : tamil
# Predicted language :assamese
#
# por momon tral bir power gol a teer e e toote pare her
# Actual language : odiya
# Predicted language :punjabi
#
# hato hard lo over ar gern a a os but her e er  cot toe era to o
#
# Actual language : odiya
# Predicted language :odiya
#
# herer e is a wor e in ar ye sad sa
#
# Actual language : tamil
# Predicted language :punjabi
#
# par not you iterl ol
#
# Actual language : odiya
# Predicted language :punjabi
#
# afte an pos scru wal hal go ahop ape od roe sar
#
# Actual language : odiya
# Predicted language :punjabi
#
# momer haero mor chilerol in
#
# Actual language : tamil
# Predicted language :assamese
#
# lo o ol ta ta ad lo hap peta
#
# Actual language : odiya
# Predicted language :punjabi
#
# or ova crew ofo ar halo neari ore
#
# Actual language : tamil
# Predicted language :punjabi
#
# roral anod gol on her ho
#
# Actual language : tamil
# Predicted language :assamese
#
# a cal blo cup o pato a to eat blo ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# a man tatco tarte as posh ea me
#
# Actual language : odiya
# Predicted language :punjabi
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# momer haero mor chilerol in
#
# Actual language : tamil
# Predicted language :assamese
#
# a groupn n an and  women a en ande ena
#
# Actual language : tamil
# Predicted language :punjabi
#
# oo gro or wot fo te es er her hor e
#
# Actual language : assamese
# Predicted language :assamese
#
# oes a hayo e rur  el so
#
# Actual language : punjabi
# Predicted language :punjabi
#
# temar  canish ol yet hav e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# buti how for go par at o le i a al ete to are
#
# Actual language : odiya
# Predicted language :punjabi
#
# e ar o o a o and te hav a
#
# Actual language : tamil
# Predicted language :punjabi
#
#  room won o ten o opo eol e ter her gol
#
# Actual language : assamese
# Predicted language :assamese
#
# ash a ben tec to to ash no ol  se
#
# Actual language : punjabi
# Predicted language :punjabi
#
# as a dron rep ten wol ho of a
#
# Actual language : punjabi
# Predicted language :assamese
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# wutene how an atol far ei i cas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ah a gor eten to a so soma e hol rul har yo sho bom o
#
# Actual language : odiya
# Predicted language :punjabi
#
# i wol are pi tol hol  to at er on atter the at bicto the hold ho er
#
# Actual language : odiya
# Predicted language :punjabi
#
# lo o ol ta ta ad lo hap peta
#
# Actual language : odiya
# Predicted language :punjabi
#
# om d mein a cal ha tas ha oi at roa at o ta lush
#
# Actual language : odiya
# Predicted language :punjabi
#
# ro more or es sil first ton o
#
# Actual language : assamese
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# not co betoa ta aol ra bo yo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# te ac fanl ar a a fronan who ha  trol or fo a ah te te er to ater ar
#
# Actual language : odiya
# ...
# Predicted language :punjabi
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# i you on a tho o on a
#
# Actual language : tamil
# Predicted language :tamil
#
# ooo o o ofor tomer vordof mo povers e afom teon cns e
#
# Actual language : assamese
# Predicted language :assamese
#
# her r the tre a ho lan
#
# Actual language : tamil
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
#  eer a e her who her ties senoos
#
# Actual language : assamese
# Predicted language :punjabi
#
# l are that trouble boles si a ol to for the the te blo o ar go  a
#
# Actual language : odiya
# Predicted language :odiya
#
# oom hon er a or wo who l and er
#
# Actual language : tamil
# Predicted language :assamese
#
# bon la re sho s ru  no
#
# Actual language : tamil
# Predicted language :punjabi
#
# fo thava e the cross ot taca a yo hol
#
# Actual language : odiya
# Predicted language :punjabi
#
# as a dron rep ten wol ho of a
#
# Actual language : punjabi
# Predicted language :assamese
#
# o is yui fas se  a e e e ane ane aas
#
# Actual language : punjabi
# Predicted language :punjabi
#
# hower o erot ta rerter
#
# Actual language : odiya
# Predicted language :punjabi
#
# rofer hom mor fo or oore mor ars e har emoer mor
#
# Actual language : assamese
# Predicted language :assamese
#
# go o cole lo a ca alee bro be ar a a
#
# Actual language : odiya
# Predicted language :odiya
#
# braar ta cal ro po a a or ol er taher craca ha er a
#
# Actual language : odiya
# Predicted language :odiya
#
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wor wom ol o or mo mom boo o mo an o
#
# Actual language : assamese
# Predicted language :assamese
#
# moo o o o to e wo otu te has yo er
#
# Actual language : assamese
# Predicted language :assamese
#
# monor ro o won a ton tor
#
# Actual language : assamese
# Predicted language :assamese
#
# fo thava e the cross ot taca a yo hol
#
# Actual language : odiya
# Predicted language :punjabi
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# tat hor book a gru pepoprable er
#
# Actual language : odiya
# Predicted language :assamese
#
# braar ta cal ro po a a or ol er taher craca ha er a
#
# Actual language : odiya
# Predicted language :odiya
#
# wo hatha coa o oer o erer
#
# Actual language : odiya
# Predicted language :assamese
#
# ihero a her her ow her eohor
#
# Actual language : tamil
# Predicted language :assamese
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# rewl pa ha e a or an si feral fa ee
#
# Actual language : tamil
# Predicted language :punjabi
#
# go po mor in o siler te over son ote feer who
#
# Actual language : assamese
# Predicted language :assamese
#
# ono ho mol her ha yo oe ter
#
# Actual language : tamil
# Predicted language :assamese
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o ar but u bo perver e tu abl mo aaa rola shop the cur sa her gor te tru a brble
#
# Actual language : odiya
# Predicted language :odiya
#
# you hore wel ot a il ar o e
#
# Actual language : tamil
# Predicted language :punjabi
#
# ther her msasse has reso
#
# Actual language : assamese
# Predicted language :punjabi
#
# pare youo over cane a you are oho o boroval er ar but antinho ish ercol a
#
# Actual language : odiya
# Predicted language :punjabi
#
# e om orn e wo on aon an
#
# Actual language : tamil
# Predicted language :assamese
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi
#
# awho yo o gre o te o tan to er
#
# Actual language : assamese
# Predicted language :punjabi
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# moel o e  a a e e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wo pesul who fin oosin thevos te
#
# Actual language : assamese
# Predicted language :punjabi
#
# wol nat e hole tera te ham
#
# Actual language : tamil
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# a wo on wer wor or halo mor o aes
#
# Actual language : tamil
# Predicted language :assamese
#
# not icoa ha had to aitl chal os ol toe to es
#
# Actual language : odiya
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# but who hor tatoo far o
#
# Actual language : odiya
# Predicted language :punjabi
#
# ala a ltl e ar atat bo wo ar trar yo ber ar cacter oro dele shata i a ar a
#
# Actual language : odiya
# Predicted language :odiya
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ho glar i o clas o to in ye ar tat e tle or
#
# Actual language : odiya
# Predicted language :punjabi
#
# othe er or the woon ater hoso her e er ter her mot o a moe
#
# Actual language : assamese
# Predicted language :punjabi
#
# grooto to er  for who ase tho ter mos tor oe
#
# Actual language : assamese
# Predicted language :assamese
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wo eo atero en o tooer tee ho or fer forter te
#
# Actual language : assamese
# Predicted language :assamese
#
# how ver e oo a hor wo bo to fo a od cosho s te a wova a shartol tan fro to o tla a
#
# Actual language : odiya
# Predicted language :odiya
#
# wer roomer il for rover to woer te lom es atiser o
#
# Actual language : assamese
# Predicted language :assamese
#
# atol tru wor a oho na a o e bo a
#
# Actual language : odiya
# Predicted language :punjabi
#
# molon a reverl thitel on o
#
# Actual language : tamil
# Predicted language :punjabi
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# the nope har rop ru o wit per hapa howr
#
# Actual language : odiya
# Predicted language :punjabi
#
# afte an pos scru wal hal go ahop ape od roe sar
#
# Actual language : odiya
# Predicted language :punjabi
#
# no herber lo yoan aver
#
# Actual language : tamil
# Predicted language :punjabi
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goom al ole on orofer e horm
#
# Actual language : assamese
# Predicted language :assamese
#
# glu ta to ho lo ar car that te e tu to
#
# Actual language : odiya
# Predicted language :odiya
#
# hower o erot ta rerter
#
# Actual language : odiya
# Predicted language :punjabi
#
# widen  a  e odor ha e sees er
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ma e ser ans ana but
#
# Actual language : punjabi
# Predicted language :punjabi
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah con or te a ler broa to pa o asen o heal car
#
# Actual language : odiya
# Predicted language :odiya
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# gro and group en mom te  fer vo you hon over bo
#
# Actual language : assamese
# Predicted language :assamese
#
# ah andwee rop yr a for lottle on  herm of tro
#
# Actual language : punjabi
# Predicted language :assamese
#
# ala a ltl e ar atat bo wo ar trar yo ber ar cacter oro dele shata i a ar a
#
# Actual language : odiya
# Predicted language :odiya
#
# ee et t e t t t i      i i i i i i i e
#
# Actual language : tamil
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# to wom ooeras ril er wo ofo fhoh
#
# Actual language : assamese
# Predicted language :assamese
#
# frome e a te o to ar paa hat  over fur otos o te do oshul bo or
#
# Actual language : odiya
# Predicted language :odiya
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o mo no wo o mo o hor o
#
# Actual language : assamese
# Predicted language :assamese
#
# or love te eatom thera
#
# Actual language : odiya
# Predicted language :punjabi
#
# wutene how an atol far ei i cas
#
# Actual language : punjabi
# Predicted language :punjabi
#
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# oa ran o on o to ong  lo can yote her tan er the wor
#
# Actual language : tamil
# Predicted language :tamil
#
# rofer hom mor fo or oore mor ars e har emoer mor
#
# Actual language : assamese
# Predicted language :assamese
#
# hemo how eron eror romer haron
#
# Actual language : tamil
# Predicted language :punjabi
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ou  mo her mir o your
#
# Actual language : assamese
# Predicted language :assamese
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# boral am at i perle lole an
#
# Actual language : tamil
# Predicted language :punjabi
#
# ha i tho ole hanto fa
#
# Actual language : tamil
# Predicted language :punjabi
#
# ol me on he ate aon ao
#
# Actual language : tamil
# Predicted language :punjabi
#
# rom  who ao wo  wo more o worble o who ano o
#
# Actual language : tamil
# Predicted language :assamese
#
# eomo and o or to her
#
# Actual language : assamese
# Predicted language :assamese
#
# te ac fanl ar a a fronan who ha  trol or fo a ah te te er to ater ar
#
# Actual language : odiya
# Predicted language :odiya
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o mo no wo o mo o hor o
#
# Actual language : assamese
# Predicted language :assamese
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# moel o e  a a e e as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a glota a ad cate toble goher a
#
# Actual language : odiya
# Predicted language :punjabi
#
# bar ho copraa o purver i ter par e feto er to rol or
#
# Actual language : odiya
# Predicted language :punjabi
#
# a mora ate a cau de li goere ta aro
#
# Actual language : odiya
# Predicted language :punjabi
#
#  pe o maser e ofol te
#
# Actual language : tamil
# Predicted language :punjabi
#
# a groupn n an and  women a en ande ena
#
# Actual language : tamil
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# mo woo ors mo as he o ser gro
#
# Actual language : assamese
# Predicted language :assamese
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# bok cavl ac al  ol to co col toco taa
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# o wor mordern for is on wo for weor wo abben a hes he sor
#
# Actual language : assamese
# Predicted language :assamese
#
# who i te a sufer pe to merper who e
#
# Actual language : assamese
# Predicted language :punjabi
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ma as e ately o you e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# her bo wor her who o wo
#
# Actual language : assamese
# Predicted language :assamese
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# or wot for boto wo es fel ol tol om
#
# Actual language : assamese
# Predicted language :assamese
#
# ooo o o ofor tomer vordof mo povers e afom teon cns e
#
# Actual language : assamese
# Predicted language :assamese
#
# ma e ser ans ana but
#
# Actual language : punjabi
# Predicted language :punjabi
#
# or herer as the hom i o
#
# Actual language : assamese
# Predicted language :punjabi
#
# wer roomer il for rover to woer te lom es atiser o
#
# Actual language : assamese
# Predicted language :assamese
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi
#
# a refer o an sor hier torthe  her till te
#
# Actual language : assamese
# Predicted language :punjabi
#
# frome e a te o to ar paa hat  over fur otos o te do oshul bo or
#
# Actual language : odiya
# Predicted language :odiya
#
# moterd er do a taed an
#
# Actual language : punjabi
# Predicted language :punjabi
#
# wo omo mofol  o on who
#
# Actual language : assamese
# Predicted language :assamese
#
# emoo who forho we or ser ofnfir eher e a her e wos or
#
# Actual language : assamese
# Predicted language :assamese
#
# her on er wol movig had a er a no e
#
# Actual language : tamil
# Predicted language :tamil
#
# ash a ben tec to to ash no ol  se
#
# Actual language : punjabi
# Predicted language :punjabi
#
# mo woo ors mo as he o ser gro
#
# Actual language : assamese
# Predicted language :assamese
#
# roo we il foe a om who
#
# Actual language : assamese
# Predicted language :assamese
#
# mo woo ors mo as he o ser gro
#
# Actual language : assamese
# Predicted language :assamese
#
# oois o who herfor ho wor on motel for mon
#
# Actual language : assamese
# Predicted language :assamese
#
# i wol are pi tol hol  to at er on atter the at bicto the hold ho er
#
# Actual language : odiya
# Predicted language :punjabi
#
# tat hor book a gru pepoprable er
#
# Actual language : odiya
# Predicted language :assamese
#
# the wo wer ar oe  ol er on all e
#
# Actual language : tamil
# Predicted language :tamil
#
# not icoa ha had to aitl chal os ol toe to es
#
# Actual language : odiya
# Predicted language :punjabi
#
# hemo how eron eror romer haron
#
# Actual language : tamil
# Predicted language :punjabi
#
# emoo who forho we or ser ofnfir eher e a her e wos or
#
# Actual language : assamese
# Predicted language :assamese
#
# col co n ar ar home ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# goom al ole on orofer e horm
#
# Actual language : assamese
# Predicted language :assamese
#
# wor a aro han on ha fel
#
# Actual language : tamil
# Predicted language :tamil
#
# boa of or her te shot evers e ton a
#
# Actual language : odiya
# Predicted language :punjabi
#
# tho la car leha the ol  sho blo ar cover lo bor a sthe oop a to a por
#
# Actual language : odiya
# Predicted language :odiya
#
# wo pesul who fin oosin thevos te
#
# Actual language : assamese
# Predicted language :punjabi
#
# a mora ate a cau de li goere ta aro
#
# Actual language : odiya
# Predicted language :punjabi
#
# coma o apo e me pa too a  torher toar ose
#
# Actual language : odiya
# Predicted language :punjabi
#
# buti how for go par at o le i a al ete to are
#
# Actual language : odiya
# Predicted language :punjabi
#
# her the pass a word o me a te er are
#
# Actual language : tamil
# Predicted language :punjabi
#
# hev ae a ner an me an
#
# Actual language : tamil
# Predicted language :punjabi
#
# mo moo herm the wor lon relo la ar o eere ol ol fool ros fon
#
# Actual language : tamil
# Predicted language :assamese
#
# moror wor wor hom  her her om eon pro horro
#
# Actual language : assamese
# Predicted language :assamese
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# the nol ar der have do at to e to all aa car
#
# Actual language : odiya
# Predicted language :punjabi
#
# awho yo o gre o te o tan to er
#
# Actual language : assamese
# Predicted language :punjabi
#
# wo who for nor mor wo e here o enfor ma yen
#
# Actual language : assamese
# Predicted language :assamese
#
# ah con or te a ler broa to pa o asen o heal car
#
# Actual language : odiya
# Predicted language :odiya
#
# go o cole lo a ca alee bro be ar a a
#
# Actual language : odiya
# Predicted language :odiya
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# le wo hes shor ae har
#
# Actual language : odiya
# Predicted language :punjabi
#
# as a dron rep ten wol ho of a
#
# Actual language : punjabi
# Predicted language :assamese
#
# tat hor book a gru pepoprable er
#
# Actual language : odiya
# Predicted language :assamese
#
# comelohas wole trome  tra to sho to ho o ar par perver troo
#
# Actual language : odiya
# Predicted language :odiya
#
#  a ov hol er ivl totes shop o  ho e he the a tavel a or year o sho how
#
# Actual language : odiya
# Predicted language :punjabi
#
# mo ol he e ol pes ad ser sho setat
#
# Actual language : punjabi
# Predicted language :punjabi

# %%
print ('Accuracy :', accuracy/count*100)
print (accuracy, count)
# Out:
# Accuracy : 50.67750677506775
# 374 738

# %%
pprint(set(misclassified))
# Out:
# {('  e to cel he e wosh you\n', 'tamil', 'punjabi'),
#  ('  er at a an er as verer wo hes aer\n', 'tamil', 'punjabi'),
#  (' a ov hol er ivl totes shop o  ho e he the a tavel a or year o sho how\n',
#   'odiya',
#   'punjabi'),
#  (' eer a e her who her ties senoos\n', 'assamese', 'punjabi'),
#  (' hor wer on not non hoor an more terepor it \n', 'tamil', 'assamese'),
#  (' pe o maser e ofol te\n', 'tamil', 'punjabi'),
#  ('a ah ol ot have long\n', 'tamil', 'odiya'),
#  ('a cal blo cup o pato a to eat blo ar\n', 'odiya', 'punjabi'),
#  ('a cala lou a o ho ol eri\n', 'tamil', 'assamese'),
#  ('a glota a ad cate toble goher a\n', 'odiya', 'punjabi'),
#  ('a goo shan ar  at to par tey wush\n', 'odiya', 'punjabi'),
#  ('a groupn n an and  women a en ande ena\n', 'tamil', 'punjabi'),
#  ('a man tatco tarte as posh ea me\n', 'odiya', 'punjabi'),
#  ('a mirl hon worve mo wor ol ol o han a all\n', 'tamil', 'assamese'),
#  ('a mon or a wol wel if your ae\n', 'tamil', 'assamese'),
#  ('a mora ate a cau de li goere ta aro\n', 'odiya', 'punjabi'),
#  ('a o er an has long a ot ho aton\n', 'tamil', 'punjabi'),
#  ('a o i poher han had tol eo s ta\n', 'odiya', 'punjabi'),
#  ('a om who bar at an oit line oo\n', 'tamil', 'punjabi'),
#  ('a par ca a no wers ca we te cot ever ter\n', 'odiya', 'punjabi'),
#  ('a refer o an sor hier torthe  her till te\n', 'assamese', 'punjabi'),
#  ('a warer ors ter an hof won et\n', 'tamil', 'punjabi'),
#  ('a wo on wer wor or halo mor o aes\n', 'tamil', 'assamese'),
#  ('a women non e bor ter on  terter\n', 'tamil', 'punjabi'),
#  ('aah a ol crebl aateo el ra praen aal o\n', 'odiya', 'punjabi'),
#  ('abat caprad eor craps foh rul bos ot te a oer a ca to\n',
#   'odiya',
#   'punjabi'),
#  ('afte an pos scru wal hal go ahop ape od roe sar\n', 'odiya', 'punjabi'),
#  ('ah a a ye o how wor her o fam so\n', 'tamil', 'assamese'),
#  ('ah a gor eten to a so soma e hol rul har yo sho bom o\n',
#   'odiya',
#   'punjabi'),
#  ('ah andwee rop yr a for lottle on  herm of tro\n', 'punjabi', 'assamese'),
#  ('ah boosh so la a ant o  o eve tad yo et  a yoare\n', 'odiya', 'punjabi'),
#  ('ah o who on o ro hom\n', 'tamil', 'assamese'),
#  ('ahe yer e year is e as\n', 'tamil', 'punjabi'),
#  ('al ger o o er a shoe er to her on\n', 'tamil', 'assamese'),
#  ('al ron oper eor rel throg te or\n', 'tamil', 'assamese'),
#  ('ale wo i aoe at a atot co you o e lat\n', 'odiya', 'punjabi'),
#  ('ana man a rad oable eh co s asho a o a ar\n', 'odiya', 'punjabi'),
#  ('ao how ha a on hoye who o ier ate\n', 'tamil', 'punjabi'),
#  ('ar or  hever on on ho wol o\n', 'tamil', 'assamese'),
#  ('areod oe mo boof o or rola aoo om trog to\n', 'tamil', 'assamese'),
#  ('arer o o wol af a ihar ho\n', 'tamil', 'punjabi'),
#  ('as a dron rep ten wol ho of a\n', 'punjabi', 'assamese'),
#  ('at oh te can co al toom at the to had do tho ta bat he  cowera\n',
#   'odiya',
#   'punjabi'),
#  ('atol tru wor a oho na a o e bo a\n', 'odiya', 'punjabi'),
#  ('av moe to caofle  toval bush her ar ta hales ar\n', 'odiya', 'punjabi'),
#  ('awho yo o gre o te o tan to er\n', 'assamese', 'punjabi'),
#  ('bar ho copraa o purver i ter par e feto er to rol or\n', 'odiya', 'punjabi'),
#  ('blu ate slaro wo pa cravel shel a herwo ater a aten a\n',
#   'odiya',
#   'punjabi'),
#  ('blue borbl had her a pa te hava wit tethe ta acatl powol a terar\n',
#   'odiya',
#   'punjabi'),
#  ('boa of or her te shot evers e ton a\n', 'odiya', 'punjabi'),
#  ('bok cavl ac al  ol to co col toco taa\n', 'odiya', 'punjabi'),
#  ('bon la re sho s ru  no \n', 'tamil', 'punjabi'),
#  ('boral am at i perle lole an\n', 'tamil', 'punjabi'),
#  ('buro owo o  wo where a more me o hor od\n', 'tamil', 'assamese'),
#  ('but who hor tatoo far o\n', 'odiya', 'punjabi'),
#  ('buti how for go par at o le i a al ete to are\n', 'odiya', 'punjabi'),
#  ('col co n ar ar home ar \n', 'odiya', 'punjabi'),
#  ('coma o apo e me pa too a  torher toar ose\n', 'odiya', 'punjabi'),
#  ('e ar o o a o and te hav a\n', 'tamil', 'punjabi'),
#  ('e mo bron artar to wer of sot tave palo boer to aa\n', 'odiya', 'punjabi'),
#  ('e om orn e wo on aon an\n', 'tamil', 'assamese'),
#  ('ee et t e t t t i      i i i i i i i e\n', 'tamil', 'punjabi'),
#  ('eer lar man o yeur or i\n', 'tamil', 'assamese'),
#  ('er ave e in el er hes aner in he en aneahe an has that ma\n',
#   'tamil',
#   'punjabi'),
#  ('ewa ar coble trua tet part o birls\n', 'odiya', 'punjabi'),
#  ('fo thava e the cross ot taca a yo hol\n', 'odiya', 'punjabi'),
#  ('goger who ro lot moover fermn earl o\n', 'tamil', 'assamese'),
#  ('gro wor or at proper at wee a wor ru bo\n', 'tamil', 'assamese'),
#  ('h e yeah ho his go ter a her did your a arter\n', 'tamil', 'punjabi'),
#  ('ha i tho ole hanto fa\n', 'tamil', 'punjabi'),
#  ('ha par ho go at a pa ca foe  pa  bluo ol a a\n', 'odiya', 'punjabi'),
#  ('hah o lottebo wol e ar\n', 'odiya', 'punjabi'),
#  ('haner wol revero o ow aner ol  an\n', 'tamil', 'assamese'),
#  ('har women or mo wer sa o wo we m o\n', 'tamil', 'assamese'),
#  ('he to oor tal a e  a child an bre ea tear tolea\n', 'odiya', 'punjabi'),
#  ('hemo how eron eror romer haron\n', 'tamil', 'punjabi'),
#  ('her  who o wo how ham ao har food\n', 'tamil', 'assamese'),
#  ('her gil ar a o wa wor\n', 'tamil', 'punjabi'),
#  ('her r the tre a ho lan\n', 'tamil', 'punjabi'),
#  ('her the pass a word o me a te er are\n', 'tamil', 'punjabi'),
#  ('her verther e peraby drew at\n', 'tamil', 'punjabi'),
#  ('herer e is a wor e in ar ye sad sa\n', 'tamil', 'punjabi'),
#  ('hev ae a ner an me an\n', 'tamil', 'punjabi'),
#  ('hhavor ol a ho drover on the\n', 'tamil', 'assamese'),
#  ('ho glar i o clas o to in ye ar tat e tle or\n', 'odiya', 'punjabi'),
#  ('ho l mun o durn yera os o a\n', 'tamil', 'assamese'),
#  ('hower o erot ta rerter\n', 'odiya', 'punjabi'),
#  ('hower ol an on a ture bre su \n', 'tamil', 'punjabi'),
#  ('i aall moru bat gorhola o ato a  soshe hor la o\n', 'odiya', 'punjabi'),
#  ('i bote ash wot  ho tor caveawosh \n', 'odiya', 'punjabi'),
#  ('i wol are pi tol hol  to at er on atter the at bicto the hold ho er\n',
#   'odiya',
#   'punjabi'),
#  ('ihero a her her ow her eohor\n', 'tamil', 'assamese'),
#  ('lac as hope i go a ton\n', 'odiya', 'punjabi'),
#  ('le wo hes shor ae har\n', 'odiya', 'punjabi'),
#  ('lo o e om a patola o ean ro e ah out\n', 'odiya', 'punjabi'),
#  ('lo o ol ta ta ad lo hap peta\n', 'odiya', 'punjabi'),
#  ('ma her ro as an of er eil a\n', 'tamil', 'punjabi'),
#  ('man at fot te wod toca dear cral o\n', 'odiya', 'punjabi'),
#  ('maol wa or awa ha so pas ol or\n', 'tamil', 'punjabi'),
#  ('mo moo herm the wor lon relo la ar o eere ol ol fool ros fon\n',
#   'tamil',
#   'assamese'),
#  ('mo o o wo war n o for\n', 'tamil', 'assamese'),
#  ('mo son ron to in o o\n', 'tamil', 'punjabi'),
#  ('mo wol mo ror as over en worl fo\n', 'tamil', 'assamese'),
#  ('moer oher r moah av er\n', 'tamil', 'punjabi'),
#  ('mohare wittle go hor er\n', 'tamil', 'assamese'),
#  ('molon a reverl thitel on o\n', 'tamil', 'punjabi'),
#  ('momer haero mor chilerol in\n', 'tamil', 'assamese'),
#  ('no herber lo yoan aver\n', 'tamil', 'punjabi'),
#  ('not co betoa ta aol ra bo yo a\n', 'odiya', 'punjabi'),
#  ('not icoa ha had to aitl chal os ol toe to es\n', 'odiya', 'punjabi'),
#  ('o all no you yor o or \n', 'tamil', 'assamese'),
#  ('o erbl u are han aongo ith e  none eron\n', 'tamil', 'punjabi'),
#  ('o fowol aar te a to a ar ton tatibo e troa ca\n', 'odiya', 'punjabi'),
#  ('o furn no erver cam o ar\n', 'tamil', 'punjabi'),
#  ('o on fomo a  haro her\n', 'tamil', 'punjabi'),
#  ('o who wo did  sul boto heera tran e he trar  ar pass o no qi aper\n',
#   'odiya',
#   'punjabi'),
#  ('o wo o o  fol avr aer\n', 'tamil', 'assamese'),
#  ('oar wan ale ho wer o in herlon her\n', 'tamil', 'punjabi'),
#  ('oh who ro ahe i iver ata a\n', 'tamil', 'punjabi'),
#  ('oho fa o i fi oh too  hor o on fol\n', 'tamil', 'assamese'),
#  ('ol me on he ate aon ao\n', 'tamil', 'punjabi'),
#  ('ol wo trew ua ter of a ro ba t who ye\n', 'tamil', 'punjabi'),
#  ('om d mein a cal ha tas ha oi at roa at o ta lush\n', 'odiya', 'punjabi'),
#  ('on who hor  me thon o o pobe \n', 'tamil', 'assamese'),
#  ('ono ho mol her ha yo oe ter\n', 'tamil', 'assamese'),
#  ('oom hon er a or wo who l and er\n', 'tamil', 'assamese'),
#  ('oome or er asterte co er ser\n', 'assamese', 'punjabi'),
#  ('ooo en so eoe o wron\n', 'tamil', 'assamese'),
#  ('opar rove l heer te  tear aa terpefoco e ler or\n', 'odiya', 'punjabi'),
#  ('or er oo for as is in e fo\n', 'assamese', 'punjabi'),
#  ('or herer as the hom i o\n', 'assamese', 'punjabi'),
#  ('or i wonl ever o fer yer a\n', 'tamil', 'assamese'),
#  ('or love te eatom thera\n', 'odiya', 'punjabi'),
#  ('or ova crew ofo ar halo neari ore\n', 'tamil', 'punjabi'),
#  ('othe er or the woon ater hoso her e er ter her mot o a moe\n',
#   'assamese',
#   'punjabi'),
#  ('owe her so wi the lo\n', 'tamil', 'punjabi'),
#  ('par not you iterl ol\n', 'odiya', 'punjabi'),
#  ('pare youo over cane a you are oho o boroval er ar but antinho ish ercol a\n',
#   'odiya',
#   'punjabi'),
#  ('por momon tral bir power gol a teer e e toote pare her', 'odiya', 'punjabi'),
#  ('rever howeer eter aran mane\n', 'tamil', 'punjabi'),
#  ('rewl pa ha e a or an si feral fa ee\n', 'tamil', 'punjabi'),
#  ('ro more or es sil first ton o\n', 'assamese', 'punjabi'),
#  ('rol o mo i her o o co ofher e\n', 'tamil', 'assamese'),
#  ('rom  who ao wo  wo more o worble o who ano o\n', 'tamil', 'assamese'),
#  ('ror an erb of rol an eamo lan or\n', 'tamil', 'punjabi'),
#  ('roral anod gol on her ho \n', 'tamil', 'assamese'),
#  ('rorl o o ol pole le eea\n', 'tamil', 'assamese'),
#  ('ruba wil wol a a  a lo ho e\n', 'tamil', 'punjabi'),
#  ('run at er lo or a lote hane ad mu sutli ah\n', 'tamil', 'punjabi'),
#  ('rutel aw  e e ol on e ha an an\n', 'tamil', 'punjabi'),
#  ('sha ave toable gro o e to e apa\n', 'odiya', 'punjabi'),
#  ('tat hor book a gru pepoprable er\n', 'odiya', 'assamese'),
#  ('ter own we o who of fie\n', 'tamil', 'assamese'),
#  ('the gral wel oo ora o movn\n', 'tamil', 'assamese'),
#  ('the nol ar der have do at to e to all aa car\n', 'odiya', 'punjabi'),
#  ('the nope har rop ru o wit per hapa howr\n', 'odiya', 'punjabi'),
#  ('the par i o bor on eo o i e wal  a a\n', 'odiya', 'tamil'),
#  ('ther her msasse has reso\n', 'assamese', 'punjabi'),
#  ('uaia her a had i will  mae\n', 'tamil', 'punjabi'),
#  ('who ho la ol eyar oro\n', 'tamil', 'assamese'),
#  ('who i te a sufer pe to merper who e\n', 'assamese', 'punjabi'),
#  ('wo hatha coa o oer o erer\n', 'odiya', 'assamese'),
#  ('wo ite sero son to o\n', 'assamese', 'punjabi'),
#  ('wo o for fono  asol hes\n', 'tamil', 'assamese'),
#  ('wo omer infaconye to to\n', 'assamese', 'punjabi'),
#  ('wo pesul who fin oosin thevos te\n', 'assamese', 'punjabi'),
#  ('wo re oh ooh wo a alo lin ara\n', 'tamil', 'punjabi'),
#  ('wol nat e hole tera te ham \n', 'tamil', 'punjabi'),
#  ('wole a plocpa co cower coa ar\n', 'odiya', 'punjabi'),
#  ('wor as ac ca ra o too\n', 'tamil', 'punjabi'),
#  ('wor ho morer lon preve raher\n', 'tamil', 'assamese'),
#  ('yer e her tol the rar ol oer herm thel ar ha om sha of e ere\n',
#   'tamil',
#   'punjabi'),
#  ('yhae or i a te o to erer\n', 'tamil', 'punjabi'),
#  ('yo an waol esis e har as e ho ner hofer her e ho\n', 'assamese', 'punjabi'),
#  ('you hore wel ot a il ar o e\n', 'tamil', 'punjabi'),
#  ('you or on true o ere\n', 'tamil', 'assamese')}

# %%
count = 0
accuracy = 0
misclassified = [] 

for i in range(100):
    file = "test_assamese.txt"
    lines = random.choice(open(file, errors = "ignore").readlines())
    if len(lines) <= 20: 
        continue
    count += 1    
    print (lines)
    print ("Actual language : assamese")
    predicted = identify_language(lines, 'test_sentences')

    if (predicted == language): 
        accuracy += 1
    else:
        misclassified.append((lines, language, predicted))
# Out:
# moo o he ro foer who to ov her so tie e wosmoter e o oe
#
# Actual language : assamese
# Predicted language :assamese
#
# hero o o go ofer o wo to yo hom
#
# Actual language : assamese
# Predicted language :assamese
#
# oome or er asterte co er ser
#
# Actual language : assamese
# Predicted language :punjabi
#
# o mo no wo o mo o hor o
#
# Actual language : assamese
# Predicted language :assamese
#
# hero o o go ofer o wo to yo hom
#
# Actual language : assamese
# Predicted language :assamese
#
# mo woo ors mo as he o ser gro
#
# Actual language : assamese
# Predicted language :assamese
#
# morker cermot wor on wo vers e e ver e
#
# Actual language : assamese
# Predicted language :assamese
#
# ther her msasse has reso
#
# Actual language : assamese
# Predicted language :punjabi
#
# morker cermot wor on wo vers e e ver e
#
# Actual language : assamese
# Predicted language :assamese
#
# oois o who herfor ho wor on motel for mon
#
# Actual language : assamese
# Predicted language :assamese
#
# ro more or es sil first ton o
#
# Actual language : assamese
# Predicted language :punjabi
#
# goom al ole on orofer e horm
#
# Actual language : assamese
# Predicted language :assamese
#
# o mo no wo o mo o hor o
#
# Actual language : assamese
# Predicted language :assamese
#
# wo eo atero en o tooer tee ho or fer forter te
#
# Actual language : assamese
# Predicted language :assamese
#
# mor wor an o on so mos sis ten ho herall pos fim wo
#
# Actual language : assamese
# Predicted language :assamese
#
# er won ho on o e thel wer  po the fil or her o the paseo or hoo
#
# Actual language : assamese
# Predicted language :assamese
#
# oho mo ies o horan ho ero in wo
#
# Actual language : assamese
# Predicted language :assamese
#
# oho mo ies o horan ho ero in wo
#
# Actual language : assamese
# Predicted language :assamese
#
#  room won o ten o opo eol e ter her gol
#
# Actual language : assamese
# Predicted language :assamese
#
# othe er or the woon ater hoso her e er ter her mot o a moe
#
# Actual language : assamese
# Predicted language :punjabi
#
# wer roomer il for rover to woer te lom es atiser o
#
# Actual language : assamese
# Predicted language :assamese
#
# her terer good her hor won in e om oon coe rus oroer
#
# Actual language : assamese
# Predicted language :assamese
#
# morker cermot wor on wo vers e e ver e
#
# Actual language : assamese
# Predicted language :assamese
#
# wo wo wo om o more an
#
# Actual language : assamese
# Predicted language :assamese
#
# oo gro or wot fo te es er her hor e
#
# Actual language : assamese
# Predicted language :assamese
#
# rom who wo o has my eart ol wohe hoer
#
# Actual language : assamese
# Predicted language :assamese
#
# who re o te o o hos yo e
#
# Actual language : assamese
# Predicted language :assamese
#
# or herer as the hom i o
#
# Actual language : assamese
# Predicted language :punjabi
#
# othe er or the woon ater hoso her e er ter her mot o a moe
#
# Actual language : assamese
# Predicted language :punjabi
#
# ther her msasse has reso
#
# Actual language : assamese
# Predicted language :punjabi
#
# wo omer infaconye to to
#
# Actual language : assamese
# Predicted language :punjabi
#
# wo pesul who fin oosin thevos te
#
# Actual language : assamese
# Predicted language :punjabi
#
# oper wo wor en ho ol e fol
#
# Actual language : assamese
# Predicted language :assamese
#
# ro more or es sil first ton o
#
# Actual language : assamese
# Predicted language :punjabi
#
# owho  ron gron oon hom o boo to
#
# Actual language : assamese
# Predicted language :assamese
#
# oo gro or wot fo te es er her hor e
#
# Actual language : assamese
# Predicted language :assamese
#
# er won ho on o e thel wer  po the fil or her o the paseo or hoo
#
# Actual language : assamese
# Predicted language :assamese
#
# her terer good her hor won in e om oon coe rus oroer
#
# Actual language : assamese
# Predicted language :assamese
#
# awho yo o gre o te o tan to er
#
# Actual language : assamese
# Predicted language :punjabi
#
# awho yo o gre o te o tan to er
#
# Actual language : assamese
# Predicted language :punjabi
#
# omo more oro is n i hom to wo te wor mo tho moso  her ho
#
# Actual language : assamese
# Predicted language :assamese
#
# wo omer infaconye to to
#
# Actual language : assamese
# Predicted language :punjabi
#
# wo omer infaconye to to
#
# Actual language : assamese
# Predicted language :punjabi
#
# omo more oro is n i hom to wo te wor mo tho moso  her ho
#
# Actual language : assamese
# Predicted language :assamese
#
# moo o he ro foer who to ov her so tie e wosmoter e o oe
#
# Actual language : assamese
# Predicted language :assamese
#
# rom who wo o has my eart ol wohe hoer
#
# Actual language : assamese
# Predicted language :assamese
#
# othe er or the woon ater hoso her e er ter her mot o a moe
#
# Actual language : assamese
# Predicted language :punjabi
#
# goom al ole on orofer e horm
#
# Actual language : assamese
# Predicted language :assamese
#
# oa e sor o so wo mo ol or o wofor olon
#
# Actual language : assamese
# Predicted language :assamese
#
# oo gro or wot fo te es er her hor e
#
# Actual language : assamese
# Predicted language :assamese
#
# er won ho on o e thel wer  po the fil or her o the paseo or hoo
#
# Actual language : assamese
# Predicted language :assamese
#
# othe er or the woon ater hoso her e er ter her mot o a moe
#
# Actual language : assamese
# Predicted language :punjabi
#
# wer more folol fon oll tin te haner ter coon
#
# Actual language : assamese
# Predicted language :assamese

# %%
print ('Accuracy :', accuracy/count*100)
print (accuracy, count)
# Out:
# Accuracy : 30.18867924528302
# 16 53

# %%
count = 0
accuracy = 0
misclassified = [] 

for i in range(80):
    file = "test_odiya.txt"
    lines = random.choice(open(file, errors = "ignore").readlines())
    if len(lines) <= 20: 
        continue
    count += 1    
    print (lines)
    print ("Actual language : odiya")
    predicted = identify_language(lines, 'test_sentences')

    if (predicted == language): 
        accuracy += 1
    else:
        misclassified.append((lines, language, predicted))
# Out:
# e mo bron artar to wer of sot tave palo boer to aa
#
# Actual language : odiya
# Predicted language :punjabi
#
# a mora ate a cau de li goere ta aro
#
# Actual language : odiya
# Predicted language :punjabi
#
# go o cole lo a ca alee bro be ar a a
#
# Actual language : odiya
# Predicted language :odiya
#
# but who hor tatoo far o
#
# Actual language : odiya
# Predicted language :punjabi
#
# om d mein a cal ha tas ha oi at roa at o ta lush
#
# Actual language : odiya
# Predicted language :punjabi
#
# l gruper pash soshoot we a ro tover ine other si ora
#
# Actual language : odiya
# Predicted language :punjabi
#
# col co n ar ar home ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# a man tatco tarte as posh ea me
#
# Actual language : odiya
# Predicted language :punjabi
#
# sha ave toable gro o e to e apa
#
# Actual language : odiya
# Predicted language :punjabi
#
# the par i o bor on eo o i e wal  a a
#
# Actual language : odiya
# Predicted language :tamil
#
# buti how for go par at o le i a al ete to are
#
# Actual language : odiya
# Predicted language :punjabi
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# l gruper pash soshoot we a ro tover ine other si ora
#
# Actual language : odiya
# Predicted language :punjabi
#
# fo thava e the cross ot taca a yo hol
#
# Actual language : odiya
# Predicted language :punjabi
#
# i bote ash wot  ho tor caveawosh
#
# Actual language : odiya
# Predicted language :punjabi
#
# a mora ate a cau de li goere ta aro
#
# Actual language : odiya
# Predicted language :punjabi
#
#  a ov hol er ivl totes shop o  ho e he the a tavel a or year o sho how
#
# Actual language : odiya
# Predicted language :punjabi
#
# l gruper pash soshoot we a ro tover ine other si ora
#
# Actual language : odiya
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi
#
# frome e a te o to ar paa hat  over fur otos o te do oshul bo or
#
# Actual language : odiya
# Predicted language :odiya
#
# aah a ol crebl aateo el ra praen aal o
#
# Actual language : odiya
# Predicted language :punjabi
#
# got can ar e more e cara o bo to ave i porola ers far bote a
#
# Actual language : odiya
# Predicted language :odiya
#
# lo o e om a patola o ean ro e ah out
#
# Actual language : odiya
# Predicted language :punjabi
#
# braar ta cal ro po a a or ol er taher craca ha er a
#
# Actual language : odiya
# Predicted language :odiya
#
# hah o lottebo wol e ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# le wo hes shor ae har
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah boosh so la a ant o  o eve tad yo et  a yoare
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah a gor eten to a so soma e hol rul har yo sho bom o
#
# Actual language : odiya
# Predicted language :punjabi
#
# pare youo over cane a you are oho o boroval er ar but antinho ish ercol a
#
# Actual language : odiya
# Predicted language :punjabi
#
# per or ah seter a nat top poi the tol ate i but te gerten to ol t caca
#
# Actual language : odiya
# Predicted language :odiya
#
# a gol  had wo a hasho a tut ol ar to we a tu ro por caa anor a e a ar
#
# Actual language : odiya
# Predicted language :odiya
#
# ale wo i aoe at a atot co you o e lat
#
# Actual language : odiya
# Predicted language :punjabi
#
# ha par ho go at a pa ca foe  pa  bluo ol a a
#
# Actual language : odiya
# Predicted language :punjabi
#
# ha par ho go at a pa ca foe  pa  bluo ol a a
#
# Actual language : odiya
# Predicted language :punjabi
#
# abat caprad eor craps foh rul bos ot te a oer a ca to
#
# Actual language : odiya
# Predicted language :punjabi
#
# o ar but u bo perver e tu abl mo aaa rola shop the cur sa her gor te tru a brble
#
# Actual language : odiya
# Predicted language :odiya
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# frome e a te o to ar paa hat  over fur otos o te do oshul bo or
#
# Actual language : odiya
# Predicted language :odiya
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# man at fot te wod toca dear cral o
#
# Actual language : odiya
# Predicted language :punjabi
#
# he to oor tal a e  a child an bre ea tear tolea
#
# Actual language : odiya
# Predicted language :punjabi
#
# ale wo i aoe at a atot co you o e lat
#
# Actual language : odiya
# Predicted language :punjabi
#
# go o cole lo a ca alee bro be ar a a
#
# Actual language : odiya
# Predicted language :odiya
#
# bok cavl ac al  ol to co col toco taa
#
# Actual language : odiya
# Predicted language :punjabi
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# opar rove l heer te  tear aa terpefoco e ler or
#
# Actual language : odiya
# Predicted language :punjabi
#
# the par i o bor on eo o i e wal  a a
#
# Actual language : odiya
# Predicted language :tamil
#
# or love te eatom thera
#
# Actual language : odiya
# Predicted language :punjabi
#
# por momon tral bir power gol a teer e e toote pare her
# Actual language : odiya
# Predicted language :punjabi
#
# l are that trouble boles si a ol to for the the te blo o ar go  a
#
# Actual language : odiya
# Predicted language :odiya
#
# a man tatco tarte as posh ea me
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah boosh so la a ant o  o eve tad yo et  a yoare
#
# Actual language : odiya
# Predicted language :punjabi
#
# lo o ol ta ta ad lo hap peta
#
# Actual language : odiya
# Predicted language :punjabi
#
# ah boosh so la a ant o  o eve tad yo et  a yoare
#
# Actual language : odiya
# Predicted language :punjabi
#
# abat caprad eor craps foh rul bos ot te a oer a ca to
#
# Actual language : odiya
# Predicted language :punjabi
#
# o fowol aar te a to a ar ton tatibo e troa ca
#
# Actual language : odiya
# Predicted language :punjabi
#
# a goo shan ar  at to par tey wush
#
# Actual language : odiya
# Predicted language :punjabi
#
# the nope har rop ru o wit per hapa howr
#
# Actual language : odiya
# Predicted language :punjabi
#
# bol il bole  ado gor aar or trac to rol  er l a your aer or
#
# Actual language : odiya
# Predicted language :odiya
#
# ale wo i aoe at a atot co you o e lat
#
# Actual language : odiya
# Predicted language :punjabi
#
# comelohas wole trome  tra to sho to ho o ar par perver troo
#
# Actual language : odiya
# Predicted language :odiya
#
# a gol  had wo a hasho a tut ol ar to we a tu ro por caa anor a e a ar
#
# Actual language : odiya
# Predicted language :odiya
#
# e mo bron artar to wer of sot tave palo boer to aa
#
# Actual language : odiya
# Predicted language :punjabi
#
# glu ta to ho lo ar car that te e tu to
#
# Actual language : odiya
# Predicted language :odiya
#
# ala a ltl e ar atat bo wo ar trar yo ber ar cacter oro dele shata i a ar a
#
# Actual language : odiya
# Predicted language :odiya
#
# at oh te can co al toom at the to had do tho ta bat he  cowera
#
# Actual language : odiya
# Predicted language :punjabi
#
# a glota a ad cate toble goher a
#
# Actual language : odiya
# Predicted language :punjabi
#
# col co n ar ar home ar
#
# Actual language : odiya
# Predicted language :punjabi
#
# i wol are pi tol hol  to at er on atter the at bicto the hold ho er
#
# Actual language : odiya
# Predicted language :punjabi
#
# h bus fom er e co l roboshu wol to o patto ape
#
# Actual language : odiya
# Predicted language :punjabi
#
# bok cavl ac al  ol to co col toco taa
#
# Actual language : odiya
# Predicted language :punjabi
#
# a par ca a no wers ca we te cot ever ter
#
# Actual language : odiya
# Predicted language :punjabi

# %%
print ('Accuracy :', accuracy/count*100)
print (accuracy, count)
# Out:
# Accuracy : 77.02702702702703
# 57 74

# %%
count = 0
accuracy = 0
misclassified = [] 

for i in range(30):
    file = "test_punjabi.txt"
    lines = random.choice(open(file, errors = "ignore").readlines())
    if len(lines) <= 20: 
        continue
    count += 1    
    print (lines)
    print ("Actual language : punjabi")
    predicted = identify_language(lines, 'test_sentences')

    if (predicted == language): 
        accuracy += 1
    else:
        misclassified.append((lines, language, predicted))
# Out:
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# mo ol he e ol pes ad ser sho setat
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ah thro wol er il wo a ee as
#
# Actual language : punjabi
# Predicted language :punjabi
#
# mortur a hap ne amee is ash i tat a easit
#
# Actual language : punjabi
# Predicted language :punjabi
#
# hownis kast hern l at ser hode dor te
#
# Actual language : punjabi
# Predicted language :punjabi
#
# group ar har though ata her er a y fer ru mera as sidn asuh
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ree ter at e er sir a is
#
# Actual language : punjabi
# Predicted language :punjabi
#
# oe sar er as mors ar
#
# Actual language : punjabi
# Predicted language :punjabi
#
# ah andwee rop yr a for lottle on  herm of tro
#
# Actual language : punjabi
# Predicted language :assamese
#
# as a dron rep ten wol ho of a
#
# Actual language : punjabi
# Predicted language :assamese
#
# ash ean er it ter havie car
#
# Actual language : punjabi
# Predicted language :punjabi
#
# goere er e wor as if has is
# Actual language : punjabi
# Predicted language :punjabi
#
# rer consiner i eres ane i nin met
#
# Actual language : punjabi
# Predicted language :punjabi
#
# howm nos had ein an  an e i as
#
# Actual language : punjabi
# Predicted language :punjabi
#
#   wo per in ter wish tac to war
#
# Actual language : punjabi
# Predicted language :punjabi
#
# temar  canish ol yet hav e
#
# Actual language : punjabi
# Predicted language :punjabi
#
# rer consiner i eres ane i nin met
#
# Actual language : punjabi
# Predicted language :punjabi
#
# me hower youter hot to ter wet smooth s
#
# Actual language : punjabi
# Predicted language :punjabi

# %%
print ('Accuracy :', accuracy/count*100)
print (accuracy, count)
# Out:
# Accuracy : 90.0
# 18 20

# %%
count = 0
accuracy = 0
misclassified = [] 

for i in range(200):
    file = "test_tamil.txt"
    lines = random.choice(open(file, errors = "ignore").readlines())
    if len(lines) <= 20: 
        continue
    count += 1    
    print (lines)
    print ("Actual language : tamil")
    predicted = identify_language(lines, 'test_sentences')

    if (predicted == language): 
        accuracy += 1
    else:
        misclassified.append((lines, language, predicted))
# Out:
# throm gormor o om o your wol
#
# Actual language : tamil
# Predicted language :assamese
#
# her on er wol movig had a er a no e
#
# Actual language : tamil
# Predicted language :tamil
#
# o gol revo anebl ter ao
#
# Actual language : tamil
# Predicted language :punjabi
#
# you are ono on o e li or ferver rol  o
#
# Actual language : tamil
# Predicted language :assamese
#
# ooe ho and oor al is
#
# Actual language : tamil
# Predicted language :punjabi
#
# the an e fen ar ou ho wor ae
# Actual language : tamil
# Predicted language :punjabi
#
# mo son ron to in o o
#
# Actual language : tamil
# Predicted language :punjabi
#
# her her rer fon a len an wo od for anas he her fore
#
# Actual language : tamil
# Predicted language :assamese
#
# ol me on he ate aon ao
#
# Actual language : tamil
# Predicted language :punjabi
#
# h ayou ar hao the ferverle hery he tur
#
# Actual language : tamil
# Predicted language :punjabi
#
# on who hor  me thon o o pobe
#
# Actual language : tamil
# Predicted language :assamese
#
# a warer ors ter an hof won et
#
# Actual language : tamil
# Predicted language :punjabi
#
# to han an on a o verel wo wor earl wel rom
#
# Actual language : tamil
# Predicted language :tamil
#
# i you on a tho o on a
#
# Actual language : tamil
# Predicted language :tamil
#
# her gil ar a o wa wor
#
# Actual language : tamil
# Predicted language :punjabi
#
# to han an on a o verel wo wor earl wel rom
#
# Actual language : tamil
# Predicted language :tamil
#
# ror an erb of rol an eamo lan or
#
# Actual language : tamil
# Predicted language :punjabi
#
# grop  yer her won i ho tan eed
#
# Actual language : tamil
# Predicted language :assamese
#
# onman lal an com olo a o her
#
# Actual language : tamil
# Predicted language :punjabi
#
# a on ado e  i maes an sol you an her boe
#
# Actual language : tamil
# Predicted language :punjabi
#
# e ar o o a o and te hav a
#
# Actual language : tamil
# Predicted language :punjabi
#
# momer haero mor chilerol in
#
# Actual language : tamil
# Predicted language :assamese
#
# uaia her a had i will  mae
#
# Actual language : tamil
# Predicted language :punjabi
#
# a her ho heever hor be a o ov a bon an an en an
#
# Actual language : tamil
# Predicted language :tamil
#
# maol wa or awa ha so pas ol or
#
# Actual language : tamil
# Predicted language :punjabi
#
# or ova crew ofo ar halo neari ore
#
# Actual language : tamil
# Predicted language :punjabi
#
# on omiher  mo mor ye o o o o ol gor o
#
# Actual language : tamil
# Predicted language :assamese
#
#  o over hope for ta ole
#
# Actual language : tamil
# Predicted language :assamese
#
# oar wan ale ho wer o in herlon her
#
# Actual language : tamil
# Predicted language :punjabi
#
# ran canon to ter robler o wor oo
#
# Actual language : tamil
# Predicted language :assamese
#
# gro wor or at proper at wee a wor ru bo
#
# Actual language : tamil
# Predicted language :assamese
#
# her the pass a word o me a te er are
#
# Actual language : tamil
# Predicted language :punjabi
#
# or ova crew ofo ar halo neari ore
#
# Actual language : tamil
# Predicted language :punjabi
#
# a o o peramen ner o remen ho  fromfon
#
# Actual language : tamil
# Predicted language :assamese
#
# ahe yer e year is e as
#
# Actual language : tamil
# Predicted language :punjabi
#
# ha i tho ole hanto fa
#
# Actual language : tamil
# Predicted language :punjabi
#
# oar wan ale ho wer o in herlon her
#
# Actual language : tamil
# Predicted language :punjabi
#
# wo whoare a o  woer trew of the i of  her ho feree
#
# Actual language : tamil
# Predicted language :assamese
#
# who ho hol her we rong o ban o or ea the lo oar how her e lo o amos lo
#
# Actual language : tamil
# Predicted language :tamil
#
# hower ol an on a ture bre su
#
# Actual language : tamil
# Predicted language :punjabi
#
# a o er an has long a ot ho aton
#
# Actual language : tamil
# Predicted language :punjabi
#
# er ave e in el er hes aner in he en aneahe an has that ma
#
# Actual language : tamil
# Predicted language :punjabi
#
# her gil ar a o wa wor
#
# Actual language : tamil
# Predicted language :punjabi
#
# or ova crew ofo ar halo neari ore
#
# Actual language : tamil
# Predicted language :punjabi
#
# ono iver oferon yoo roer hie
#
# Actual language : tamil
# Predicted language :assamese
#
# romo o o to hos o rol
#
# Actual language : tamil
# Predicted language :assamese
#
# a on ado e  i maes an sol you an her boe
#
# Actual language : tamil
# Predicted language :punjabi
#
# the wo wer ar oe  ol er on all e
#
# Actual language : tamil
# Predicted language :tamil
#
# a ho ol ar o er at te youah of s
#
# Actual language : tamil
# Predicted language :punjabi
#
# her on er wol movig had a er a no e
#
# Actual language : tamil
# Predicted language :tamil
#
# aa how no the ber ho
#
# Actual language : tamil
# Predicted language :punjabi
#
# yhae or i a te o to erer
#
# Actual language : tamil
# Predicted language :punjabi
#
# obol ha al a tone aer
#
# Actual language : tamil
# Predicted language :punjabi
#
# areod oe mo boof o or rola aoo om trog to
#
# Actual language : tamil
# Predicted language :assamese
#
# mo o o wo war n o for
#
# Actual language : tamil
# Predicted language :assamese
#
# lo her rong  elon who wor her
#
# Actual language : tamil
# Predicted language :assamese
#
# yer e her tol the rar ol oer herm thel ar ha om sha of e ere
#
# Actual language : tamil
# Predicted language :punjabi
#
# mo who hor o lo mo sin how her
#
# Actual language : tamil
# Predicted language :assamese
#
# re on hah rol irble mo o rora no a e
#
# Actual language : tamil
# Predicted language :assamese
#
# a rul on ot nat sa hors ter no at is gus tie
#
# Actual language : tamil
# Predicted language :punjabi
#
# grop  yer her won i ho tan eed
#
# Actual language : tamil
# Predicted language :assamese
#
# o on fomo a  haro her
#
# Actual language : tamil
# Predicted language :punjabi
#
# ron o gam  hawe you ha ho yor
#
# Actual language : tamil
# Predicted language :punjabi
#
# herl in her o hurbe ho loe
#
# Actual language : tamil
# Predicted language :punjabi
#
#  o over hope for ta ole
#
# Actual language : tamil
# Predicted language :assamese
#
# o how er ru rural a too her an o
#
# Actual language : tamil
# Predicted language :punjabi
#
# rom  who ao wo  wo more o worble o who ano o
#
# Actual language : tamil
# Predicted language :assamese
#
# boral am at i perle lole an
#
# Actual language : tamil
# Predicted language :punjabi
#
# wor a aro han on ha fel
#
# Actual language : tamil
# Predicted language :tamil
#
#   e to cel he e wosh you
#
# Actual language : tamil
# Predicted language :punjabi
#
# oh who ro ahe i iver ata a
#
# Actual language : tamil
# Predicted language :punjabi
#
# her gil ar a o wa wor
#
# Actual language : tamil
# Predicted language :punjabi
#
# wer her er en vere the
#
# Actual language : tamil
# Predicted language :punjabi
#
# hoeme alo long on ad pere  tat co the can
#
# Actual language : tamil
# Predicted language :punjabi
#
# ar hade ol o on with me i ole e
#
# Actual language : tamil
# Predicted language :punjabi
#
# lo her rong  elon who wor her
#
# Actual language : tamil
# Predicted language :assamese
#
# womer her en tan ar a wo hed a a ver fanlees hel on has in
#
# Actual language : tamil
# Predicted language :tamil
#
# areod oe mo boof o or rola aoo om trog to
#
# Actual language : tamil
# Predicted language :assamese
#
#  pe o maser e ofol te
#
# Actual language : tamil
# Predicted language :punjabi
#
# a ah ol ot have long
#
# Actual language : tamil
# Predicted language :odiya
#
# roo havel as her e rue dron lan rom er
#
# Actual language : tamil
# Predicted language :punjabi
#
# a women non e bor ter on  terter
#
# Actual language : tamil
# Predicted language :punjabi
#
#  hor wer on not non hoor an more terepor it
#
# Actual language : tamil
# Predicted language :assamese
#
# how avalttle er o ad ere i i han e on
#
# Actual language : tamil
# Predicted language :punjabi
#
# maol wa or awa ha so pas ol or
#
# Actual language : tamil
# Predicted language :punjabi
#
# o on fomo a  haro her
#
# Actual language : tamil
# Predicted language :punjabi
#
# an on o e in oven ater to hon e an
#
# Actual language : tamil
# Predicted language :punjabi
#
# rutel aw  e e ol on e ha an an
#
# Actual language : tamil
# Predicted language :punjabi
#
# mo wol mo ror as over en worl fo
#
# Actual language : tamil
# Predicted language :assamese
#
# you are ono on o e li or ferver rol  o
#
# Actual language : tamil
# Predicted language :assamese
#
# wo re oh ooh wo a alo lin ara
#
# Actual language : tamil
# Predicted language :punjabi
#
# the an e fen ar ou ho wor ae
# Actual language : tamil
# Predicted language :punjabi
#
# ah o who on o ro hom
#
# Actual language : tamil
# Predicted language :assamese
#
# a on ado e  i maes an sol you an her boe
#
# Actual language : tamil
# Predicted language :punjabi
#
# o c haen oter o ofe e ai o
#
# Actual language : tamil
# Predicted language :punjabi
#  pe o maser e ofol te
#
# Actual language : tamil
# Predicted language :punjabi
#
# ol wo trew ua ter of a ro ba t who ye
#
# Actual language : tamil
# Predicted language :punjabi
#
# here you all o of he a her n
#
# Actual language : tamil
# Predicted language :tamil
#
# a mirl hon worve mo wor ol ol o han a all
#
# Actual language : tamil
# Predicted language :assamese
#
# o all no you yor o or
#
# Actual language : tamil
# Predicted language :assamese
#
# ihero a her her ow her eohor
#
# Actual language : tamil
# Predicted language :assamese
#
# a her ho heever hor be a o ov a bon an an en an
#
# Actual language : tamil
# Predicted language :tamil
#
# a groupn n an and  women a en ande ena
#
# Actual language : tamil
# Predicted language :punjabi
#
# ah a a ye o how wor her o fam so
#
# Actual language : tamil
# Predicted language :assamese
#
# ran canon to ter robler o wor oo
#
# Actual language : tamil
# Predicted language :assamese
#
# wo whoare a o  woer trew of the i of  her ho feree
#
# Actual language : tamil
# Predicted language :assamese
#
# a on ado e  i maes an sol you an her boe
#
# Actual language : tamil
# Predicted language :punjabi
#
# womer her en tan ar a wo hed a a ver fanlees hel on has in
#
# Actual language : tamil
# Predicted language :tamil
#
# you or on true o ere
#
# Actual language : tamil
# Predicted language :assamese
#
# rol o mo i her o o co ofher e
#
# Actual language : tamil
# Predicted language :assamese
#
# lo her rong  elon who wor her
#
# Actual language : tamil
# Predicted language :assamese
#
# mohare wittle go hor er
#
# Actual language : tamil
# Predicted language :assamese
#
# a groupn n an and  women a en ande ena
#
# Actual language : tamil
# Predicted language :punjabi
#
# her r the tre a ho lan
#
# Actual language : tamil
# Predicted language :punjabi
#
# ol wo trew ua ter of a ro ba t who ye
#
# Actual language : tamil
# Predicted language :punjabi
#
# hemo how eron eror romer haron
#
# Actual language : tamil
# Predicted language :punjabi
#
# hale her who ra dron er as you at
#
# Actual language : tamil
# Predicted language :punjabi
#
# a o i work ho e ave al
#
# Actual language : tamil
# Predicted language :assamese
#
# rever howeer eter aran mane
#
# Actual language : tamil
# Predicted language :punjabi
#
# the wo wer ar oe  ol er on all e
#
# Actual language : tamil
# Predicted language :tamil
#
# a rol mor i hel her on the hon  ha paat han her
#
# Actual language : tamil
# Predicted language :tamil
#
# eer lar man o yeur or i
#
# Actual language : tamil
# Predicted language :assamese
#
# o gol revo anebl ter ao
#
# Actual language : tamil
# Predicted language :punjabi
#
# h ayou ar hao the ferverle hery he tur
#
# Actual language : tamil
# Predicted language :punjabi
#
# uaia her a had i will  mae
#
# Actual language : tamil
# Predicted language :punjabi
#
# eer lar man o yeur or i
#
# Actual language : tamil
# Predicted language :assamese
#
# oar wan ale ho wer o in herlon her
#
# Actual language : tamil
# Predicted language :punjabi
#
# onman lal an com olo a o her
#
# Actual language : tamil
# Predicted language :punjabi
#
# ruba wil wol a a  a lo ho e
#
# Actual language : tamil
# Predicted language :punjabi
#
#  o over hope for ta ole
#
# Actual language : tamil
# Predicted language :assamese
#
# yer e her tol the rar ol oer herm thel ar ha om sha of e ere
#
# Actual language : tamil
# Predicted language :punjabi
#
# a wo on wer wor or halo mor o aes
#
# Actual language : tamil
# Predicted language :assamese
#
# ogorer porer te wen wash low e
#
# Actual language : tamil
# Predicted language :punjabi
#
# ar hade ol o on with me i ole e
#
# Actual language : tamil
# Predicted language :punjabi
#
# rorl o o ol pole le eea
#
# Actual language : tamil
# Predicted language :assamese
#
# gro wor or at proper at wee a wor ru bo
#
# Actual language : tamil
# Predicted language :assamese
#
# to han an on a o verel wo wor earl wel rom
#
# Actual language : tamil
# Predicted language :tamil

# %%
print ('Accuracy :', accuracy/count*100)
print (accuracy, count)
# Out:
# Accuracy : 54.74452554744526
# 75 137
